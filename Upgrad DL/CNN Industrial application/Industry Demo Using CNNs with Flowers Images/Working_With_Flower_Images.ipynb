# %% [markdown]
# # Working with Images
#
# In this notebook, we will go through the end-to-end pipeline of training conv nets, i.e. organising the data into directories, preprocessing, data augmentation, model building etc.

# %%
# Download flowers-20210317T060850Z-001.zip the dataset (Don't run this again in the same session, it will again download the data)
# !wget https://datasetsgun.s3.amazonaws.com/upgrad/flowers-20210317T060850Z-001.zip
# Out:
# --2021-04-08 13:41:07--  https://datasetsgun.s3.amazonaws.com/upgrad/flowers-20210317T060850Z-001.zip
# Resolving datasetsgun.s3.amazonaws.com (datasetsgun.s3.amazonaws.com)... 52.217.88.36
# Connecting to datasetsgun.s3.amazonaws.com (datasetsgun.s3.amazonaws.com)|52.217.88.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 481436104 (459M) [application/zip]
# Saving to: ‘flowers-20210317T060850Z-001.zip’
#
# flowers-20210317T06 100%[===================>] 459.13M  11.2MB/s    in 44s
#
# 2021-04-08 13:41:52 (10.4 MB/s) - ‘flowers-20210317T060850Z-001.zip’ saved [481436104/481436104]

# %%
## Unzip (Run only once to unzip the downloaded dataset)
# !unzip flowers-20210317T060850Z-001.zip
# Out:
# Archive:  flowers-20210317T060850Z-001.zip
#   inflating: flowers/dandelion/7368449232_c99f49b2e6_n.jpg
#   inflating: flowers/dandelion/8989067485_aab399460b_n.jpg
#   inflating: flowers/dandelion/8979087213_28f572174c.jpg
#   inflating: flowers/dandelion/8689302980_9bd2f7b9fe_n.jpg
#   inflating: flowers/dandelion/8079778274_f2a400f749_n.jpg
#   inflating: flowers/dandelion/8719388716_1a392c4c0e_n.jpg
#   inflating: flowers/dandelion/7808545612_546cfca610_m.jpg
#   inflating: flowers/dandelion/8737699225_19e0c9f0fa_m.jpg
#   inflating: flowers/dandelion/8757650550_113d7af3bd.jpg
#   inflating: flowers/dandelion/8880158802_6e10a452c7_m.jpg
#   inflating: flowers/dandelion/7401173270_ebaf04c9b0_n.jpg
#   inflating: flowers/dandelion/8963359346_65ca69c59d_n.jpg
#   inflating: flowers/dandelion/9188647508_3b56e62f69.jpg
#   inflating: flowers/dandelion/7132605107_f5e033d725_n.jpg
#   inflating: flowers/dandelion/8739657154_6db14796c9.jpg
#   inflating: flowers/dandelion/6968202872_cfcb5b77fb.jpg
#   inflating: flowers/dandelion/8738317694_eca2ce3bfc_n.jpg
#   inflating: flowers/dandelion/8915661673_9a1cdc3755_m.jpg
#   inflating: flowers/dandelion/80846315_d997645bea_n.jpg
#   inflating: flowers/sunflower/9904127656_f76a5a4811_m.jpg
#   inflating: flowers/sunflower/9558627290_353a14ba0b_m.jpg
#   inflating: flowers/sunflower/9681915384_b3b646dc92_m.jpg
#   inflating: flowers/sunflower/9558628596_722c29ec60_m.jpg
#   inflating: flowers/sunflower/969913643_9d5cd2fe45_m.jpg
#   inflating: flowers/dandelion/9300335851_cdf1cef7a9.jpg
#   inflating: flowers/sunflower/9535500195_543d0b729b.jpg
#   inflating: flowers/sunflower/9555824387_32b151e9b0_m.jpg
#   inflating: flowers/dandelion/8935456132_8dc4d3b679_n.jpg
#   inflating: flowers/dandelion/7184780734_3baab127c2_m.jpg
#   inflating: flowers/sunflower/9610098411_f1613c8e14.jpg
#   inflating: flowers/sunflower/9783416751_b2a03920f7_n.jpg
#   inflating: flowers/sunflower/9538283930_0faea083bb_n.jpg
#   inflating: flowers/sunflower/9564240106_0577e919da_n.jpg
#   inflating: flowers/sunflower/9558630626_52a1b7d702_m.jpg
#   inflating: flowers/sunflower/9825716455_f12bcc8d4e_n.jpg
#   inflating: flowers/sunflower/9651392844_77f90589ba_n.jpg
#   inflating: flowers/sunflower/9738792160_00cbcc99c8_n.jpg
#   inflating: flowers/sunflower/9610374042_bb16cded3d.jpg
#   inflating: flowers/rose/5234278003_d827fcd73b_m.jpg
#   inflating: flowers/dandelion/9517326597_5d116a0166.jpg
#   inflating: flowers/sunflower/9588522189_db6166f67f.jpg
#   inflating: flowers/rose/7187035716_5d0fb95c31_n.jpg
#   inflating: flowers/rose/483444865_65962cea07_m.jpg
#   inflating: flowers/rose/9458445402_79e4dfa89c.jpg
#   inflating: flowers/sunflower/9610373748_b9cb67bd55.jpg
#   inflating: flowers/sunflower/9555827829_74e6f60f1d_m.jpg
#   inflating: flowers/sunflower/9558632814_e78a780f4f.jpg
#   inflating: flowers/dandelion/8842317179_d59cf218cb_n.jpg
#   inflating: flowers/dandelion/flickr.py
#   inflating: flowers/rose/5002453148_5a7bbcce64_n.jpg
#   inflating: flowers/sunflower/9599534035_ae4df582b6.jpg
#   inflating: flowers/sunflower/9610371852_179e7781ce.jpg
#   inflating: flowers/sunflower/9699724719_a8439cc0fd_n.jpg
#   inflating: flowers/rose/6111589202_8b9555364c_m.jpg
#   inflating: flowers/rose/8742493617_c2a9bf854f_m.jpg
#   inflating: flowers/rose/5002455332_9de0b1e85f_n.jpg
#   inflating: flowers/rose/7461897646_3203dbe067_n.jpg
#   inflating: flowers/rose/6255593451_b8a3aa8f7a_m.jpg
#   inflating: flowers/rose/5001858821_731d128f20_n.jpg
#   inflating: flowers/rose/5777669976_a205f61e5b.jpg
#   inflating: flowers/rose/5001854143_d868390640_n.jpg
#   inflating: flowers/rose/7456914664_cdee3170c5_n.jpg
#   inflating: flowers/tulip/8908097235_c3e746d36e_n.jpg
#   inflating: flowers/rose/7481119180_7be71a322a_n.jpg
#   inflating: flowers/tulip/7082608511_f4cf233f59_n.jpg
#   inflating: flowers/rose/7461897058_3c955efe2a_n.jpg
#   inflating: flowers/rose/9164900485_605aa12da8.jpg
#   inflating: flowers/rose/6690926183_afedba9f15_n.jpg
#   inflating: flowers/rose/5292988046_a10f4b0365_n.jpg
#   inflating: flowers/tulip/8554190977_37ac747799_m.jpg
#   inflating: flowers/sunflower/9610373158_5250bce6ac_n.jpg
#   inflating: flowers/sunflower/9655029591_7a77f87500.jpg
#   inflating: flowers/tulip/8838975946_f54194894e_m.jpg
#   inflating: flowers/tulip/8892851067_79242a7362_n.jpg
#   inflating: flowers/rose/9320934277_4fb95aef5d_n.jpg
#   inflating: flowers/rose/8096324039_4db2555490.jpg
#   inflating: flowers/tulip/7266196114_c2a736a15a_m.jpg
#   inflating: flowers/tulip/8687675254_c93f50d8b0_m.jpg
#   inflating: flowers/tulip/6934951920_d43ff8b78d.jpg
#   inflating: flowers/tulip/779359602_30abcbf5bb_n.jpg
#   inflating: flowers/tulip/8713398114_bc96f1b624_n.jpg
#   inflating: flowers/tulip/8712270243_8512cf4fbd.jpg
#   inflating: flowers/rose/9309388105_12c0b8dd54_m.jpg
#   inflating: flowers/tulip/7070694881_e9a331fa4e_n.jpg
#   inflating: flowers/tulip/8454719295_4276c0e9c5_n.jpg
#   inflating: flowers/tulip/7247182064_f8d6759446_n.jpg
#   inflating: flowers/tulip/7179796338_05e8b1c87b.jpg
#   inflating: flowers/daisy/9242705328_eee8402a8d.jpg
#   inflating: flowers/tulip/8762193202_0fbf2f6a81.jpg
#   inflating: flowers/tulip/7144016605_e159b6c06b_m.jpg
#   inflating: flowers/rose/8987479080_32ab912d10_n.jpg
#   inflating: flowers/daisy/8759177308_951790e00d_m.jpg
#   inflating: flowers/daisy/8718637649_87a0d85190_n.jpg
#   inflating: flowers/tulip/924782410_94ed7913ca_m.jpg
#   inflating: flowers/tulip/6989946990_62c639ff16_n.jpg
#   inflating: flowers/tulip/7166581866_861cd081b8_n.jpg
#   inflating: flowers/rose/5402157745_a384f0583d_n.jpg
#   inflating: flowers/tulip/7166589802_8238cec83b_n.jpg
#   inflating: flowers/daisy/7924174040_444d5bbb8a.jpg
#   inflating: flowers/rose/5693502877_41c11295b6_n.jpg
#   inflating: flowers/tulip/8695367666_0809529eaf_n.jpg
#   inflating: flowers/daisy/9310226774_d1b8f5d9c9.jpg
#   inflating: flowers/daisy/8696022686_1f8d62c5cb_m.jpg
#   inflating: flowers/daisy/8719756744_34a5a83976_n.jpg
#   inflating: flowers/daisy/8740807508_0587f5b7b7.jpg
#   inflating: flowers/daisy/8085329197_41d53a21e2_n.jpg
#   inflating: flowers/daisy/8446495985_f72d851482.jpg
#   inflating: flowers/daisy/8708143485_38d084ac8c_n.jpg
#   inflating: flowers/daisy/8681746439_d6beeefbf9.jpg
#   inflating: flowers/daisy/8405273313_bef13f6c27_n.jpg
#   inflating: flowers/daisy/9350942387_5b1d043c26_n.jpg
#   inflating: flowers/flowers/tulip/9870557734_88eb3b9e3b_n.jpg
#   inflating: flowers/daisy/8127252886_96558c23d1.jpg
#   inflating: flowers/tulip/9446982168_06c4d71da3_n.jpg
#   inflating: flowers/daisy/8094774544_35465c1c64.jpg
#   inflating: flowers/daisy/8709535323_a6bea3e43f.jpg
#   inflating: flowers/flowers/tulip/9048307967_40a164a459_m.jpg
#   inflating: flowers/flowers/tulip/9378657435_89fabf13c9_n.jpg
#   inflating: flowers/daisy/9467543719_c4800becbb_m.jpg
#   inflating: flowers/flowers/tulip/9444202147_405290415b_n.jpg
#   inflating: flowers/tulip/7166544280_9d975c4d9a_n.jpg
#   inflating: flowers/tulip/8555123165_2fe57eff4f.jpg
#   inflating: flowers/flowers/tulip/9947385346_3a8cacea02_n.jpg
#   inflating: flowers/flowers/tulip/924782410_94ed7913ca_m.jpg
#   inflating: flowers/flowers/sunflower/9588522189_db6166f67f.jpg
#   inflating: flowers/flowers/sunflower/9558628596_722c29ec60_m.jpg
#   inflating: flowers/daisy/9345273630_af3550031d.jpg
#   inflating: flowers/flowers/tulip/7166546934_c97b08c9d9_n.jpg
#   inflating: flowers/flowers/tulip/8722514702_7ecc68691c.jpg
#   inflating: flowers/flowers/tulip/5674695558_61397a1584.jpg
#   inflating: flowers/flowers/tulip/6038098425_b3b4fb62cc_m.jpg
#   inflating: flowers/flowers/tulip/9976515506_d496c5e72c.jpg
#   inflating: flowers/flowers/tulip/497305666_b5d4348826_n.jpg
#   inflating: flowers/flowers/tulip/9446982168_06c4d71da3_n.jpg
#   inflating: flowers/flowers/tulip/5682463466_d3e641cb8b.jpg
#   inflating: flowers/flowers/tulip/6876631336_54bf150990.jpg
#   inflating: flowers/flowers/tulip/9831362123_5aac525a99_n.jpg
#   inflating: flowers/daisy/909609509_a05ccb8127.jpg
#   inflating: flowers/flowers/sunflower/9240129413_f240ce7866_n.jpg
#   inflating: flowers/daisy/8489463746_a9839bf7e4.jpg
#   inflating: flowers/flowers/tulip/8713392604_90631fb809_n.jpg
#   inflating: flowers/flowers/tulip/8520488975_a50d377f91.jpg
#   inflating: flowers/flowers/sunflower/9384867134_83af458a19_n.jpg
#   inflating: flowers/flowers/tulip/9947374414_fdf1d0861c_n.jpg
#   inflating: flowers/daisy/9180706736_092d43088c.jpg
#   inflating: flowers/flowers/tulip/6931489544_2f35025f7b_m.jpg
#   inflating: flowers/daisy/9515186037_3be48fe68f.jpg
#   inflating: flowers/daisy/7790614422_4557928ab9_n.jpg
#   inflating: flowers/flowers/sunflower/8929274876_17efc1774a_n.jpg
#   inflating: flowers/flowers/tulip/6989946990_62c639ff16_n.jpg
#   inflating: flowers/daisy/8742143296_fed9fa007c.jpg
#   inflating: flowers/flowers/tulip/8723767533_9145dec4bd_n.jpg
#   inflating: flowers/flowers/sunflower/9738792160_00cbcc99c8_n.jpg
#   inflating: flowers/flowers/tulip/7069622551_348d41c327_n.jpg
#   inflating: flowers/flowers/sunflower/7804213238_1d92ae5edb_m.jpg
#   inflating: flowers/flowers/sunflower/8174941335_56389b53e9_n.jpg
#   inflating: flowers/flowers/sunflower/9246304620_768d1f54d7_n.jpg
#   inflating: flowers/flowers/sunflower/8433716268_8b7b4083bc_n.jpg
#   inflating: flowers/flowers/tulip/5717951105_72b6f58838_n.jpg
#   inflating: flowers/flowers/sunflower/8929288228_6795bcb1fe.jpg
#   inflating: flowers/flowers/sunflower/7176736574_14446539cb_n.jpg
#   inflating: flowers/flowers/sunflower/9359374034_21fb12d613_n.jpg
#   inflating: flowers/flowers/sunflower/857698097_8068a2c135_n.jpg
#   inflating: flowers/flowers/sunflower/9431896325_23bf6e8761.jpg
#   inflating: flowers/rose/7461878736_a55f749faf_n.jpg
#   inflating: flowers/flowers/sunflower/9610098411_f1613c8e14.jpg
#   inflating: flowers/rose/898102603_2d5152f09a.jpg
#   inflating: flowers/rose/5001843683_ac3e5f2c87_n.jpg
#   inflating: flowers/flowers/sunflower/9555827829_74e6f60f1d_m.jpg
#   inflating: flowers/rose/5360769702_ec28c53b9e_n.jpg
#   inflating: flowers/flowers/sunflower/7586498522_4dcab1c8d2_m.jpg
#   inflating: flowers/rose/5182167964_9d1a0be0b8_n.jpg
#   inflating: flowers/flowers/tulip/8690791226_b1f015259f_n.jpg
#   inflating: flowers/flowers/sunflower/9699724719_a8439cc0fd_n.jpg
#   inflating: flowers/rose/7461899002_a3b21d0770_n.jpg
#   inflating: flowers/rose/5349865556_e3263fbdc0_n.jpg
#   inflating: flowers/flowers/sunflower/9599534035_ae4df582b6.jpg
#   inflating: flowers/flowers/sunflower/7510262868_cf7d6f6f25_n.jpg
#   inflating: flowers/flowers/sunflower/7176729812_7c053921fb_m.jpg
#   inflating: flowers/rose/5335946155_be70e11cf2_n.jpg
#   inflating: flowers/flowers/sunflower/678714585_addc9aaaef.jpg
#   inflating: flowers/rose/8747396730_966149e6fe_n.jpg
#   inflating: flowers/rose/9433167170_fa056d3175.jpg
#   inflating: flowers/rose/5990626258_697f007308_n.jpg
#   inflating: flowers/flowers/sunflower/9206376642_8348ba5c7a.jpg
#   inflating: flowers/rose/5336562212_d014ddf9ca_n.jpg
#   inflating: flowers/rose/7376473742_532364cee5_n.jpg
#   inflating: flowers/rose/7471891186_195bb02c98_n.jpg
#   inflating: flowers/flowers/sunflower/6606815161_3c4372760f.jpg
#   inflating: flowers/rose/4951581805_b049304f1b_n.jpg
#   inflating: flowers/rose/8692051081_dffa8709e7_m.jpg
#   inflating: flowers/sunflower/5004121118_e9393e60d0_n.jpg
#   inflating: flowers/rose/5001855689_e07486c44d_n.jpg
#   inflating: flowers/flowers/rose/9633056561_6f1b7e8faf_m.jpg
#   inflating: flowers/rose/4998708839_c53ee536a8_n.jpg
#   inflating: flowers/sunflower/4869189730_f47c124cda_n.jpg
#   inflating: flowers/sunflower/5995136822_8e1eed76f5_n.jpg
#   inflating: flowers/rose/5335937417_74a03b52ec_n.jpg
#   inflating: flowers/rose/5193918046_d44e4fcd75_m.jpg
#   inflating: flowers/sunflower/5139971615_434ff8ed8b_n.jpg
#   inflating: flowers/rose/7474125638_332be2863e_n.jpg
#   inflating: flowers/sunflower/5967284308_85714d8cf7_m.jpg
#   inflating: flowers/rose/5002457330_b77672da1c_n.jpg
#   inflating: flowers/sunflower/4878447831_e904c60cf8_n.jpg
#   inflating: flowers/sunflower/9497774935_a7daec5433_n.jpg
#   inflating: flowers/sunflower/4895719476_bd3b6bd6fd_n.jpg
#   inflating: flowers/rose/7820626638_3e2d712303.jpg
#   inflating: flowers/sunflower/5043404000_9bc16cb7e5_m.jpg
#   inflating: flowers/flowers/rose/9614492283_66020fb4eb_n.jpg
#   inflating: flowers/sunflower/7804213238_1d92ae5edb_m.jpg
#   inflating: flowers/rose/5001850247_33681cc95c_n.jpg
#   inflating: flowers/dandelion/7262863194_682209e9fb.jpg
#   inflating: flowers/rose/5336559428_71e8b58ab5_n.jpg
#   inflating: flowers/dandelion/8223949_2928d3f6f6_n.jpg
#   inflating: flowers/flowers/rose/9404876600_04f6d37685.jpg
#   inflating: flowers/sunflower/4872892690_52dc25b0b4.jpg
#   inflating: flowers/sunflower/5437996076_cf7e2ac32e_n.jpg
#   inflating: flowers/flowers/rose/9355706808_a9a723a8e8_n.jpg
#   inflating: flowers/dandelion/7884440256_91c033732d.jpg
#   inflating: flowers/sunflower/4932144003_cbffc89bf0.jpg
#   inflating: flowers/dandelion/7719263062_3c8a307a5d.jpg
#   inflating: flowers/dandelion/9719816995_8f211abf02_n.jpg
#   inflating: flowers/flowers/rose/9609569441_eeb8566e94.jpg
#   inflating: flowers/flowers/rose/9423755543_edb35141a3_n.jpg
#   inflating: flowers/dandelion/9726260379_4e8ee66875_m.jpg
#   inflating: flowers/sunflower/5999024446_5721493894.jpg
#   inflating: flowers/flowers/rose/9337528427_3d09b7012b.jpg
#   inflating: flowers/dandelion/7193058132_36fd883048_m.jpg
#   inflating: flowers/sunflower/6166888942_7058198713_m.jpg
#   inflating: flowers/flowers/rose/99383371_37a5ac12a3_n.jpg
#   inflating: flowers/sunflower/5937914300_bfca430439_n.jpg
#   inflating: flowers/sunflower/4895721242_89014e723c_n.jpg
#   inflating: flowers/sunflower/4933228903_9ae82d0b9d.jpg
#   inflating: flowers/sunflower/6204049536_1ac4f09232_n.jpg
#   inflating: flowers/dandelion/8691437509_9ac8441db7_n.jpg
#   inflating: flowers/flowers/rose/9433167170_fa056d3175.jpg
#   inflating: flowers/dandelion/8756906129_b05a1b26f2.jpg
#   inflating: flowers/dandelion/8956863946_f96be02aae_n.jpg
#   inflating: flowers/sunflower/5970300143_36b42437de_n.jpg
#   inflating: flowers/dandelion/9111669902_9471c3a49c_n.jpg
#   inflating: flowers/flowers/rose/9458445402_79e4dfa89c.jpg
#   inflating: flowers/flowers/rose/9702378513_229a96b754_m.jpg
#   inflating: flowers/dandelion/8981659922_7b1be892e7_m.jpg
#   inflating: flowers/dandelion/8684108_a85764b22d_n.jpg
#   inflating: flowers/flowers/rose/5001854143_d868390640_n.jpg
#   inflating: flowers/flowers/rose/5349865556_e3263fbdc0_n.jpg
#   inflating: flowers/flowers/rose/9353111163_7a89b2df35_n.jpg
#   inflating: flowers/sunflower/6113021380_7546bf7ac7_n.jpg
#   inflating: flowers/dandelion/7280217714_fb9ffccf2d_n.jpg
#   inflating: flowers/dandelion/6983105424_f33cc9b08d_m.jpg
#   inflating: flowers/dandelion/8733226215_161309f8ec.jpg
#   inflating: flowers/flowers/rose/5001858821_731d128f20_n.jpg
#   inflating: flowers/sunflower/4872284527_ff52128b97.jpg
#   inflating: flowers/dandelion/7291185504_b740bbeba4_m.jpg
#   inflating: flowers/dandelion/6953830582_8525e0423c_n.jpg
#   inflating: flowers/flowers/rose/5336562502_d697a3f0b2_n.jpg
#   inflating: flowers/sunflower/5139977283_530c508603_n.jpg
#   inflating: flowers/flowers/rose/9369421752_db1ab2a6a4_m.jpg
#   inflating: flowers/dandelion/6994931102_4667c0352e.jpg
#   inflating: flowers/dandelion/8716513637_2ba0c4e6cd_n.jpg
#   inflating: flowers/flowers/rose/5897035797_e67bf68124_n.jpg
#   inflating: flowers/dandelion/7040710179_7f86a17a3c_n.jpg
#   inflating: flowers/flowers/rose/8747396730_966149e6fe_n.jpg
#   inflating: flowers/flowers/rose/410421672_563550467c.jpg
#   inflating: flowers/flowers/rose/5002455332_9de0b1e85f_n.jpg
#   inflating: flowers/flowers/dandelion/9301891790_971dcfb35d_m.jpg
#   inflating: flowers/flowers/dandelion/98992760_53ed1d26a9.jpg
#   inflating: flowers/flowers/dandelion/8978962053_0727b41d26.jpg
#   inflating: flowers/flowers/dandelion/8980266062_8387f6cc89.jpg
#   inflating: flowers/flowers/dandelion/9111669902_9471c3a49c_n.jpg
#   inflating: flowers/flowers/dandelion/8632704230_ccafc5f7e2.jpg
#   inflating: flowers/flowers/dandelion/921252114_91e334b950.jpg
#   inflating: flowers/sunflower/4940287066_385afd9c18_m.jpg
#   inflating: flowers/flowers/dandelion/8905148527_ba9f55cd78.jpg
#   inflating: flowers/flowers/dandelion/8691437509_9ac8441db7_n.jpg
#   inflating: flowers/sunflower/6141150299_b46a64e4de.jpg
#   inflating: flowers/flowers/dandelion/8981828144_4b66b4edb6_n.jpg
#   inflating: flowers/dandelion/8724252904_db9a5104df_m.jpg
#   inflating: flowers/flowers/rose/4754734410_94d98463a5.jpg
#   inflating: flowers/dandelion/8011324555_375b7b5b0a.jpg
#   inflating: flowers/flowers/rose/9338237628_4d2547608c.jpg
#   inflating: flowers/dandelion/8780964418_7a01a7f48a_n.jpg
#   inflating: flowers/flowers/rose/4061451210_1650590c6a.jpg
#   inflating: flowers/flowers/dandelion/9617087594_ec2a9b16f6.jpg
#   inflating: flowers/dandelion/8797114213_103535743c_m.jpg
#   inflating: flowers/flowers/dandelion/8842317179_d59cf218cb_n.jpg
#   inflating: flowers/flowers/rose/4612774939_e26ec1c34d_n.jpg
#   inflating: flowers/flowers/dandelion/9517326597_5d116a0166.jpg
#   inflating: flowers/flowers/dandelion/8929523512_c87897b84e.jpg
#   inflating: flowers/flowers/dandelion/8980460785_b5e6842e59_n.jpg
#   inflating: flowers/flowers/dandelion/8797114213_103535743c_m.jpg
#   inflating: flowers/flowers/daisy/9350942387_5b1d043c26_n.jpg
#   inflating: flowers/flowers/daisy/9593034725_0062f0d24e_n.jpg
#   inflating: flowers/flowers/dandelion/flickr.pyc
#   inflating: flowers/flowers/daisy/9529916092_de70623523_n.jpg
#   inflating: flowers/flowers/daisy/9611923744_013b29e4da_n.jpg
#   inflating: flowers/flowers/daisy/7358085448_b317d11cd5.jpg
#   inflating: flowers/flowers/daisy/2901376034_cdb4bac26b_m.jpg
#   inflating: flowers/flowers/dandelion/flickr.py
#   inflating: flowers/flowers/dandelion/9759608055_9ab623d193.jpg
#   inflating: flowers/flowers/daisy/99306615_739eb94b9e_m.jpg
#   inflating: flowers/flowers/dandelion/8735646181_fa9787d4e0.jpg
#   inflating: flowers/flowers/daisy/9346508462_f0af3163f4.jpg
#   inflating: flowers/flowers/daisy/2862944799_45bc8e7302.jpg
#   inflating: flowers/flowers/dandelion/8744249948_36cb1969f8_m.jpg
#   inflating: flowers/flowers/daisy/9922116524_ab4a2533fe_n.jpg
#   inflating: flowers/flowers/daisy/6978826370_7b9aa7c7d5.jpg
#   inflating: flowers/flowers/dandelion/8980164828_04fbf64f79_n.jpg
#   inflating: flowers/flowers/daisy/7191221492_610035de7c_m.jpg
#   inflating: flowers/flowers/daisy/5577555349_2e8490259b.jpg
#   inflating: flowers/flowers/daisy/9467543719_c4800becbb_m.jpg
#   inflating: flowers/flowers/dandelion/8756906129_b05a1b26f2.jpg
#   inflating: flowers/flowers/daisy/5561775629_a2b709b3a4_n.jpg
#   inflating: flowers/flowers/daisy/5602738326_97121e007d_n.jpg
#   inflating: flowers/flowers/daisy/9595857626_979c45e5bf_n.jpg
#   inflating: flowers/flowers/daisy/9496209717_25a6ebdab6_m.jpg
#   inflating: flowers/tulip/7094271655_79a6f972c1_n.jpg
#   inflating: flowers/flowers/daisy/6776075110_1ea7a09dd4_n.jpg
#   inflating: flowers/tulip/7094415739_6b29e5215c_m.jpg
#   inflating: flowers/flowers/daisy/9515186037_3be48fe68f.jpg
#   inflating: flowers/flowers/dandelion/9300335851_cdf1cef7a9.jpg
#   inflating: flowers/flowers/daisy/33809956124_b49dcddf8f_n.jpg
#   inflating: flowers/tulip/7166552648_28b6dce578.jpg
#   inflating: flowers/flowers/dandelion/9472854850_fc9e1db673.jpg
#   inflating: flowers/flowers/daisy/9489270024_1b05f08492_m.jpg
#   inflating: flowers/tulip/8628453641_6f87755815_m.jpg
#   inflating: flowers/tulip/9378657435_89fabf13c9_n.jpg
#   inflating: flowers/flowers/daisy/34701198765_54aa641d7a_n.jpg
#   inflating: flowers/tulip/8713388322_e5ae26263b_n.jpg
#   inflating: flowers/tulip/7177682195_c29265748d_n.jpg
#   inflating: flowers/tulip/7166635566_ee240b5408_n.jpg
#   inflating: flowers/tulip/8523133474_d2c0845b54.jpg
#   inflating: flowers/flowers/daisy/4654579740_6671a53627_m.jpg
#   inflating: flowers/tulip/7166546934_c97b08c9d9_n.jpg
#   inflating: flowers/tulip/7166644048_b00a14f01b.jpg
#   inflating: flowers/tulip/8713387500_6a9138b41b_n.jpg
#   inflating: flowers/tulip/8838983024_5c1a767878_n.jpg
#   inflating: flowers/flowers/daisy/34665595995_13f76d5b60_n.jpg
#   inflating: flowers/tulip/6931748252_68f06086b3.jpg
#   inflating: flowers/daisy/8382667241_0f046cecdb_n.jpg
#   inflating: flowers/tulip/8623170936_83f4152431.jpg
#   inflating: flowers/tulip/8713394070_b24561b0a9.jpg
#   inflating: flowers/daisy/9299302012_958c70564c_n.jpg
#   inflating: flowers/tulip/7166598930_18d8686ace_n.jpg
#   inflating: flowers/tulip/8759618746_f5e39fdbf8_n.jpg
#   inflating: flowers/tulip/8712266605_3787e346cd_n.jpg
#   inflating: flowers/daisy/8616684075_71923bb771_n.jpg
#   inflating: flowers/daisy/8710109684_e2c5ef6aeb_n.jpg
#   inflating: flowers/daisy/799952628_bf836677fa_n.jpg
#   inflating: flowers/tulip/8586205168_8294e67195_n.jpg
#   inflating: flowers/daisy/99306615_739eb94b9e_m.jpg
#   inflating: flowers/tulip/7166591854_93c0dd6f8d_n.jpg
#   inflating: flowers/daisy/9204730092_a7f2182347.jpg
#   inflating: flowers/daisy/8071646795_2fdc89ab7a_n.jpg
#   inflating: flowers/tulip/8690791226_b1f015259f_n.jpg
#   inflating: flowers/daisy/8671824531_64b816949e_m.jpg
#   inflating: flowers/daisy/8938566373_d129e7af75.jpg
#   inflating: flowers/tulip/8713396140_5af8136136.jpg
#   inflating: flowers/daisy/9593034725_0062f0d24e_n.jpg
#   inflating: flowers/daisy/8619103877_d8c82c5f34_n.jpg
#   inflating: flowers/daisy/8983779970_9d3a6a3bf2_n.jpg
#   inflating: flowers/tulip/8708856019_f3be2353a4_n.jpg
#   inflating: flowers/daisy/9489270024_1b05f08492_m.jpg
#   inflating: flowers/tulip/6931715360_34edc5a372_m.jpg
#   inflating: flowers/daisy/9244082319_b1f7e2d8b0_n.jpg
#   inflating: flowers/daisy/8120563761_ed5620664f_m.jpg
#   inflating: flowers/daisy/8709110478_60d12efcd4_n.jpg
#   inflating: flowers/flowers/sunflower/9485002920_59af6f4cac.jpg
#   inflating: flowers/daisy/9120905231_329598304e.jpg
#   inflating: flowers/flowers/sunflower/9339697826_88c9c4dc50.jpg
#   inflating: flowers/daisy/813445367_187ecf080a_n.jpg
#   inflating: flowers/flowers/sunflower/9213511121_836a458021_m.jpg
#   inflating: flowers/flowers/sunflower/8174935717_d19367d502.jpg
#   inflating: flowers/flowers/sunflower/8935252770_263d682fe8_n.jpg
#   inflating: flowers/daisy/9496209717_25a6ebdab6_m.jpg
#   inflating: flowers/flowers/sunflower/7012364067_5ffc7654c9_m.jpg
#   inflating: flowers/daisy/8932490012_cc08e690ba_n.jpg
#   inflating: flowers/flowers/sunflower/9431890901_cd11bda584_n.jpg
#   inflating: flowers/flowers/sunflower/9497774935_a7daec5433_n.jpg
#   inflating: flowers/daisy/9595857626_979c45e5bf_n.jpg
#   inflating: flowers/daisy/9321854387_5f77c926cb_n.jpg
#   inflating: flowers/flowers/sunflower/9381481549_5a5d503e42_n.jpg
#   inflating: flowers/flowers/sunflower/9535500195_543d0b729b.jpg
#   inflating: flowers/flowers/sunflower/9216286162_6ceefdd1b4_m.jpg
#   inflating: flowers/flowers/sunflower/8038712786_5bdeed3c7f_m.jpg
#   inflating: flowers/flowers/sunflower/7857605684_fc86440c23.jpg
#   inflating: flowers/flowers/sunflower/9538283930_0faea083bb_n.jpg
#   inflating: flowers/flowers/sunflower/7176729016_d73ff2211e.jpg
#   inflating: flowers/flowers/sunflower/9491955955_d0b2c83834.jpg
#   inflating: flowers/daisy/9221345475_67735dbf4f_n.jpg
#   inflating: flowers/flowers/sunflower/7791014076_07a897cb85_n.jpg
#   inflating: flowers/flowers/tulip/8750288831_5e49a9f29b.jpg
#   inflating: flowers/flowers/tulip/8713394070_b24561b0a9.jpg
#   inflating: flowers/flowers/sunflower/8928658373_fdca5ff1b8.jpg
#   inflating: flowers/flowers/tulip/7177682195_c29265748d_n.jpg
#   inflating: flowers/flowers/tulip/8729501081_b993185542_m.jpg
#   inflating: flowers/flowers/sunflower/9482209981_bf7bf6022b_m.jpg
#   inflating: flowers/flowers/sunflower/8234846550_fdaf326dbe.jpg
#   inflating: flowers/flowers/sunflower/8021568040_f891223c44_n.jpg
#   inflating: flowers/flowers/tulip/6948277038_89d7ff42e2_m.jpg
#   inflating: flowers/flowers/tulip/5717950507_087513ecbf_n.jpg
#   inflating: flowers/flowers/tulip/5738195260_b3fc107aa7_n.jpg
#   inflating: flowers/flowers/sunflower/7935826214_9b57628203_m.jpg
#   inflating: flowers/flowers/tulip/5687705933_55a8c2dbac.jpg
#   inflating: flowers/flowers/tulip/8712267391_c756f18ee7_n.jpg
#   inflating: flowers/flowers/tulip/9030467406_05e93ff171_n.jpg
#   inflating: flowers/flowers/tulip/7166539842_43b7e02883.jpg
#   inflating: flowers/flowers/tulip/8601596054_33e40c2a7a.jpg
#   inflating: flowers/flowers/sunflower/7728953426_abd179ab63.jpg
#   inflating: flowers/flowers/sunflower/9497774249_7f5ae70927_m.jpg
#   inflating: flowers/flowers/tulip/8758519201_16e8d2d781_n.jpg
#   inflating: flowers/flowers/tulip/5674704952_9bd225ed9e_n.jpg
#   inflating: flowers/flowers/daisy/4538877108_3c793f7987_m.jpg
#   inflating: flowers/flowers/tulip/7166644048_b00a14f01b.jpg
#   inflating: flowers/flowers/tulip/8713387500_6a9138b41b_n.jpg
#   inflating: flowers/flowers/dandelion/8684108_a85764b22d_n.jpg
#   inflating: flowers/flowers/tulip/5433747333_869a2a172d_m.jpg
#   inflating: flowers/flowers/sunflower/8292914969_4a76608250_m.jpg
#   inflating: flowers/flowers/dandelion/8717157979_05cbc10cc1.jpg
#   inflating: flowers/flowers/tulip/5719416820_3060e3c1f0.jpg
#   inflating: flowers/flowers/dandelion/8720503800_cab5c62a34.jpg
#   inflating: flowers/flowers/dandelion/8979087213_28f572174c.jpg
#   inflating: flowers/flowers/daisy/34695914906_961f92ffcd_n.jpg
#   inflating: flowers/flowers/tulip/8614237582_74417799f4_m.jpg
#   inflating: flowers/flowers/tulip/8668973377_c69527db42_m.jpg
#   inflating: flowers/flowers/daisy/34510103621_250ee7ae64_n.jpg
#   inflating: flowers/flowers/dandelion/8740218495_23858355d8_n.jpg
#   inflating: flowers/flowers/daisy/34590677231_0ed33ccd55_n.jpg
#   inflating: flowers/flowers/daisy/5110109540_beed4ed162_m.jpg
#   inflating: flowers/flowers/dandelion/8831808134_315aedb37b.jpg
#   inflating: flowers/flowers/daisy/3640845041_80a92c4205_n.jpg
#   inflating: flowers/rose/7481118128_b2de9538b4_n.jpg
#   inflating: flowers/flowers/dandelion/8969938579_4c2032dd96_n.jpg
#   inflating: flowers/flowers/daisy/446484749_4044affcaf_n.jpg
#   inflating: flowers/flowers/daisy/7227973870_806d9d3e42_n.jpg
#   inflating: flowers/flowers/dandelion/8956863946_f96be02aae_n.jpg
#   inflating: flowers/flowers/daisy/34261196280_aa99186136_n.jpg
#   inflating: flowers/flowers/dandelion/8376558865_19c5cd6fd6_n.jpg
#   inflating: flowers/flowers/dandelion/9262004825_710346cde9_n.jpg
#   inflating: flowers/rose/6347847065_83cf87333b_n.jpg
#   inflating: flowers/rose/5349250331_05501d6557_n.jpg
#   inflating: flowers/flowers/daisy/3468498624_d082f99e98.jpg
#   inflating: flowers/flowers/daisy/3084924076_4d5c5711af_m.jpg
#   inflating: flowers/flowers/daisy/2812442552_3eed5fb9f2_m.jpg
#   inflating: flowers/flowers/daisy/5087720485_c0914fb623.jpg
#   inflating: flowers/rose/8949720453_66e8304c30.jpg
#   inflating: flowers/flowers/dandelion/9939430464_5f5861ebab.jpg
#   inflating: flowers/rose/99383371_37a5ac12a3_n.jpg
#   inflating: flowers/flowers/daisy/5981645737_29eceac291_m.jpg
#   inflating: flowers/flowers/daisy/3310644753_5607eb96a4_m.jpg
#   inflating: flowers/flowers/daisy/7749368884_1fc58c67ff_n.jpg
#   inflating: flowers/rose/7470985688_c1ee9105fa_n.jpg
#   inflating: flowers/flowers/daisy/34076975155_1faeedec90_n.jpg
#   inflating: flowers/flowers/dandelion/9853885425_4a82356f1d_m.jpg
#   inflating: flowers/rose/5419629292_2f06e4b295.jpg
#   inflating: flowers/flowers/dandelion/8733226215_161309f8ec.jpg
#   inflating: flowers/flowers/daisy/3713290261_8a66de23ab.jpg
#   inflating: flowers/flowers/dandelion/8270191872_61e47ae3b8_m.jpg
#   inflating: flowers/flowers/daisy/476856232_7c35952f40_n.jpg
#   inflating: flowers/flowers/daisy/7335886184_d06a83f640.jpg
#   inflating: flowers/flowers/dandelion/8497389500_45636fdd14.jpg
#   inflating: flowers/flowers/dandelion/8663932737_0a603ab718_n.jpg
#   inflating: flowers/rose/6053143173_991c011b23.jpg
#   inflating: flowers/flowers/dandelion/8791577794_7573712cb4_n.jpg
#   inflating: flowers/flowers/dandelion/8981659922_7b1be892e7_m.jpg
#   inflating: flowers/rose/6347846935_51e3dc2481_n.jpg
#   inflating: flowers/flowers/dandelion/8717161615_4c1e403083.jpg
#   inflating: flowers/rose/5002451854_9cf0096db0_n.jpg
#   inflating: flowers/rose/7147367479_f7a6ef0798.jpg
#   inflating: flowers/flowers/dandelion/9293460423_7fbb1e3c32_n.jpg
#   inflating: flowers/flowers/dandelion/9595369280_dd88b61814.jpg
#   inflating: flowers/flowers/daisy/4278442064_a5a598524b_m.jpg
#   inflating: flowers/rose/9353111163_7a89b2df35_n.jpg
#   inflating: flowers/flowers/tulip/8908062479_449200a1b4.jpg
#   inflating: flowers/flowers/dandelion/854593001_c57939125f_n.jpg
#   inflating: flowers/flowers/tulip/4955884820_7e4ce4d7e5_m.jpg
#   inflating: flowers/flowers/tulip/8713357842_9964a93473_n.jpg
#   inflating: flowers/flowers/tulip/6982913043_3b873c6a25.jpg
#   inflating: flowers/rose/5349248997_4b23a7344d_n.jpg
#   inflating: flowers/rose/5693489465_2d0b2e4eb2_n.jpg
#   inflating: flowers/rose/5979193298_639e877248.jpg
#   inflating: flowers/rose/5336562502_d697a3f0b2_n.jpg
#   inflating: flowers/flowers/dandelion/8754822932_948afc7cef.jpg
#   inflating: flowers/rose/6879112993_5a29208438_n.jpg
#   inflating: flowers/dandelion/8749577087_dc2521615f_n.jpg
#   inflating: flowers/rose/7456611336_52fec6b57e_n.jpg
#   inflating: flowers/rose/8674140377_ae7b0be523.jpg
#   inflating: flowers/flowers/daisy/9221345475_67735dbf4f_n.jpg
#   inflating: flowers/rose/5273722065_c85d8543c2_m.jpg
#   inflating: flowers/flowers/tulip/8759618746_f5e39fdbf8_n.jpg
#   inflating: flowers/flowers/daisy/5623010186_796ca8d29a.jpg
#   inflating: flowers/flowers/daisy/9054268881_19792c5203_n.jpg
#   inflating: flowers/dandelion/8267315764_129f2e1d77_m.jpg
#   inflating: flowers/dandelion/7280221020_98b473b20d_n.jpg
#   inflating: flowers/dandelion/8613502159_d9ea67ba63.jpg
#   inflating: flowers/rose/5001846495_56068de2da_n.jpg
#   inflating: flowers/flowers/daisy/33839388103_79cb79f7bc_n.jpg
#   inflating: flowers/dandelion/7188112181_571434b058_n.jpg
#   inflating: flowers/dandelion/8701999625_8d83138124.jpg
#   inflating: flowers/flowers/dandelion/9646730031_f3d5014416_n.jpg
#   inflating: flowers/dandelion/7141013005_d2f168c373.jpg
#   inflating: flowers/dandelion/8475758_4c861ab268_m.jpg
#   inflating: flowers/dandelion/8681169825_19a21c6bf5_m.jpg
#   inflating: flowers/dandelion/8684925862_d736e153bf_n.jpg
#   inflating: flowers/daisy/9529916092_de70623523_n.jpg
#   inflating: flowers/dandelion/8689302100_be76a16ccc_n.jpg
#   inflating: flowers/dandelion/8969938579_4c2032dd96_n.jpg
#   inflating: flowers/rose/5349865018_99cd7f985a_n.jpg
#   inflating: flowers/dandelion/8209318399_ae72aefdb5.jpg
#   inflating: flowers/dandelion/6901435398_b3192ff7f8_m.jpg
#   inflating: flowers/dandelion/6994933428_307b092ce7_m.jpg
#   inflating: flowers/dandelion/9029756865_db8891807a_n.jpg
#   inflating: flowers/dandelion/7116950607_49b19102ba_n.jpg
#   inflating: flowers/dandelion/7950892504_33142110c2.jpg
#   inflating: flowers/dandelion/7226987694_34552c3115_n.jpg
#   inflating: flowers/flowers/dandelion/8717787983_c83bdf39fe_n.jpg
#   inflating: flowers/rose/5497730366_44d758d8f5.jpg
#   inflating: flowers/dandelion/7243478942_30bf542a2d_m.jpg
#   inflating: flowers/dandelion/8980266062_8387f6cc89.jpg
#   inflating: flowers/rose/5335935585_e4a8435aab_n.jpg
#   inflating: flowers/flowers/rose/5721768347_2ec4d2247b_n.jpg
#   inflating: flowers/dandelion/8952484062_31d1d97e45.jpg
#   inflating: flowers/flowers/rose/6111589202_8b9555364c_m.jpg
#   inflating: flowers/rose/5335931029_74c01d3c35_n.jpg
#   inflating: flowers/flowers/rose/5693495337_0e42b4d9f0_n.jpg
#   inflating: flowers/sunflower/5923085671_f81dd1cf6f.jpg
#   inflating: flowers/sunflower/7176729016_d73ff2211e.jpg
#   inflating: flowers/flowers/rose/4503599544_3822e7d1be.jpg
#   inflating: flowers/sunflower/5139977579_ea2dd6a322_m.jpg
#   inflating: flowers/sunflower/9511172241_8aee411e2e.jpg
#   inflating: flowers/sunflower/6080086410_17a02dcfb8.jpg
#   inflating: flowers/flowers/rose/5336551618_16d4eea9c4_n.jpg
#   inflating: flowers/flowers/rose/5336551122_2df8fee6da_n.jpg
#   inflating: flowers/sunflower/5994586159_1dd99d66b4_n.jpg
#   inflating: flowers/sunflower/8014735546_3db46bb1fe_n.jpg
#   inflating: flowers/flowers/rose/5002459442_81825061e9_n.jpg
#   inflating: flowers/sunflower/5492906452_80943bfd04.jpg
#   inflating: flowers/dandelion/8376558865_19c5cd6fd6_n.jpg
#   inflating: flowers/flowers/rose/5863698305_04a4277401_n.jpg
#   inflating: flowers/dandelion/8966818334_483f4489be_n.jpg
#   inflating: flowers/flowers/rose/4910094611_8c7170fc95_n.jpg
#   inflating: flowers/flowers/rose/921138131_9e1393eb2b_m.jpg
#   inflating: flowers/sunflower/7176736574_14446539cb_n.jpg
#   inflating: flowers/sunflower/5231868667_f0baa71feb_n.jpg
#   inflating: flowers/tulip/8585102913_d80d3e2ff7_n.jpg
#   inflating: flowers/tulip/8673412732_f8fd690ee4_n.jpg
#   inflating: flowers/tulip/7166550328_de0d73cfa9.jpg
#   inflating: flowers/flowers/rose/4608559939_3487bf3b62_n.jpg
#   inflating: flowers/flowers/rose/5182167964_9d1a0be0b8_n.jpg
#   inflating: flowers/flowers/rose/5001852101_877cb2ae9b_n.jpg
#   inflating: flowers/sunflower/5957186948_b2afd80d70_n.jpg
#   inflating: flowers/sunflower/4932735362_6e1017140f.jpg
#   inflating: flowers/tulip/8712282563_3819afb7bc.jpg
#   inflating: flowers/sunflower/7791014076_07a897cb85_n.jpg
#   inflating: flowers/sunflower/5937355165_1dc7b2cbf9_n.jpg
#   inflating: flowers/sunflower/6125761554_4e72819ce4_m.jpg
#   inflating: flowers/flowers/rose/5002447916_8a7b7b689a_n.jpg
#   inflating: flowers/tulip/7481217920_6f65766a1c_n.jpg
#   inflating: flowers/tulip/8686013485_3c4dfbfd1f_n.jpg
#   inflating: flowers/flowers/rose/7456196534_f69c17efa3_n.jpg
#   inflating: flowers/sunflower/50987813_7484bfbcdf.jpg
#   inflating: flowers/tulip/8689672277_b289909f97_n.jpg
#   inflating: flowers/tulip/6958243974_8851425ddb_n.jpg
#   inflating: flowers/flowers/rose/7461899002_a3b21d0770_n.jpg
#   inflating: flowers/flowers/rose/475947979_554062a608_m.jpg
#   inflating: flowers/sunflower/7857605684_fc86440c23.jpg
#   inflating: flowers/sunflower/9246304620_768d1f54d7_n.jpg
#   inflating: flowers/tulip/8586205946_cda045f3f8_n.jpg
#   inflating: flowers/flowers/rose/9160289562_ab2718d19b.jpg
#   inflating: flowers/sunflower/5994572653_ea98afa3af_n.jpg
#   inflating: flowers/sunflower/5979111199_495884b578_n.jpg
#   inflating: flowers/flowers/rose/4279989256_9a48c0d194_n.jpg
#   inflating: flowers/tulip/7145978709_2d1596f462.jpg
#   inflating: flowers/daisy/9161647994_e39b65cb9c_n.jpg
#   inflating: flowers/tulip/7166560822_27b1d1d132_n.jpg
#   inflating: flowers/tulip/8712267813_f7a9be2ec5.jpg
#   inflating: flowers/sunflower/6140693467_211a135b6d.jpg
#   inflating: flowers/tulip/8605564823_7a59d3d92a.jpg
#   inflating: flowers/tulip/7166567320_0a2beb6d42_n.jpg
#   inflating: flowers/tulip/7064778965_ddcc6ee9f2.jpg
#   inflating: flowers/daisy/9611923744_013b29e4da_n.jpg
#   inflating: flowers/daisy/8322526877_95d1c0f8bc_n.jpg
#   inflating: flowers/daisy/8021540573_c56cf9070d_n.jpg
#   inflating: flowers/tulip/7166646966_41d83cd703.jpg
#   inflating: flowers/daisy/9346508462_f0af3163f4.jpg
#   inflating: flowers/daisy/8964198962_6d8593b533.jpg
#   inflating: flowers/dandelion/8647874151_aac8db2588_m.jpg
#   inflating: flowers/tulip/8712268519_f4c2c39a06_n.jpg
#   inflating: flowers/daisy/8383753520_8391dd80ee_m.jpg
#   inflating: flowers/flowers/rose/9309388105_12c0b8dd54_m.jpg
#   inflating: flowers/daisy/9094631844_1a6abca29e.jpg
#   inflating: flowers/daisy/8008258043_5457dd254b_n.jpg
#   inflating: flowers/daisy/8348621545_8f02b82662_n.jpg
#   inflating: flowers/daisy/9146733107_98b15d3892_m.jpg
#   inflating: flowers/daisy/8694909523_3ca25d449d_n.jpg
#   inflating: flowers/daisy/9054268881_19792c5203_n.jpg
#   inflating: flowers/daisy/9158041313_7a6a102f7a_n.jpg
#   inflating: flowers/daisy/9286947622_4822f4fc21.jpg
#   inflating: flowers/sunflower/4846786944_2832c5c8b8.jpg
#   inflating: flowers/flowers/rose/8983268106_dc913d17d8_m.jpg
#   inflating: flowers/tulip/7166558370_f7f68983ea_n.jpg
#   inflating: flowers/sunflower/7369484298_332f69bd88_n.jpg
#   inflating: flowers/tulip/7166567320_0a2beb6d42.jpg
#   inflating: flowers/flowers/rose/5336555402_4f6f03f5a5_n.jpg
#   inflating: flowers/flowers/rose/4809566219_88f9a1aea3.jpg
#   inflating: flowers/sunflower/821368661_4ab4343f5a.jpg
#   inflating: flowers/tulip/8394186551_28eed83a94_m.jpg
#   inflating: flowers/flowers/rose/3753920123_c7ebc18ee3.jpg
#   inflating: flowers/daisy/9922116524_ab4a2533fe_n.jpg
#   inflating: flowers/daisy/9175280426_40ecc395b8_m.jpg
#   inflating: flowers/tulip/8673416556_639f5c88f1_n.jpg
#   inflating: flowers/daisy/8063844363_db3f4dea85.jpg
#   inflating: flowers/tulip/8908062479_449200a1b4.jpg
#   inflating: flowers/tulip/7042692841_f323799c0d.jpg
#   inflating: flowers/tulip/8759597778_7fca5d434b_n.jpg
#   inflating: flowers/flowers/rose/4093390305_4010c736c9.jpg
#   inflating: flowers/flowers/sunflower/864957037_c75373d1c5.jpg
#   inflating: flowers/sunflower/6958724008_12259943a7.jpg
#   inflating: flowers/tulip/8712270665_57b5bda0a2_n.jpg
#   inflating: flowers/flowers/sunflower/8041242566_752def876e_n.jpg
#   inflating: flowers/daisy/8706810197_17b6c1f1e7.jpg
#   inflating: flowers/flowers/sunflower/8929213942_5544191250_n.jpg
#   inflating: flowers/flowers/sunflower/9484354480_07ff2ef0a6.jpg
#   inflating: flowers/flowers/sunflower/7492109308_bbbb982ebe_n.jpg
#   inflating: flowers/flowers/sunflower/9825716455_f12bcc8d4e_n.jpg
#   inflating: flowers/flowers/sunflower/9216286876_289a4779f7.jpg
#   inflating: flowers/daisy/8645839873_0151fb92bf_n.jpg
#   inflating: flowers/daisy/5459481183_18d2d49e44_m.jpg
#   inflating: flowers/daisy/8887005939_b19e8305ee.jpg
#   inflating: flowers/flowers/sunflower/7820398908_4316bbba45.jpg
#   inflating: flowers/flowers/sunflower/8071460469_a7c2c34b97_n.jpg
#   inflating: flowers/flowers/sunflower/6627521877_6e43fb3c49_m.jpg
#   inflating: flowers/flowers/sunflower/9448615838_04078d09bf_n.jpg
#   inflating: flowers/flowers/sunflower/9558630626_52a1b7d702_m.jpg
#   inflating: flowers/daisy/8008629838_c62bb2b016_n.jpg
#   inflating: flowers/daisy/8882282142_9be2524d38_m.jpg
#   inflating: flowers/daisy/9225336602_e6c392f941_n.jpg
#   inflating: flowers/flowers/sunflower/9479261399_cebfbff670_n.jpg
#   inflating: flowers/flowers/sunflower/877083343_e3338c4125.jpg
#   inflating: flowers/flowers/sunflower/969913643_9d5cd2fe45_m.jpg
#   inflating: flowers/flowers/sunflower/8174972548_0051c2d431.jpg
#   inflating: flowers/flowers/sunflower/9410186154_465642ed35.jpg
#   inflating: flowers/flowers/sunflower/6953297_8576bf4ea3.jpg
#   inflating: flowers/dandelion/7148085703_b9e8bcd6ca_n.jpg
#   inflating: flowers/flowers/sunflower/8081530919_c882d46bb0_n.jpg
#   inflating: flowers/dandelion/7179487220_56e4725195_m.jpg
#   inflating: flowers/dandelion/8791577794_7573712cb4_n.jpg
#   inflating: flowers/rose/5693495337_0e42b4d9f0_n.jpg
#   inflating: flowers/rose/8269247725_4b56cd860d_n.jpg
#   inflating: flowers/flowers/sunflower/9432335346_e298e47713_n.jpg
#   inflating: flowers/dandelion/9613826015_f345354874.jpg
#   inflating: flowers/rose/873660804_37f5c6a46e_n.jpg
#   inflating: flowers/rose/5336558870_22d0a6a318_n.jpg
#   inflating: flowers/flowers/sunflower/9461693602_710f20904f.jpg
#   inflating: flowers/dandelion/7469617666_0e1a014917.jpg
#   inflating: flowers/dandelion/8475769_3dea463364_m.jpg
#   inflating: flowers/flowers/sunflower/6908789145_814d448bb1_n.jpg
#   inflating: flowers/flowers/sunflower/7603036176_9e8967cd21.jpg
#   inflating: flowers/flowers/sunflower/6958724008_12259943a7.jpg
#   inflating: flowers/dandelion/8805314187_1aed702082_n.jpg
#   inflating: flowers/flowers/sunflower/9400904374_37723396e3_n.jpg
#   inflating: flowers/dandelion/8707349105_6d06b543b0.jpg
#   inflating: flowers/dandelion/8717157979_05cbc10cc1.jpg
#   inflating: flowers/rose/8644003462_2272de26eb.jpg
#   inflating: flowers/rose/5415782938_6ce6e4a90d_n.jpg
#   inflating: flowers/dandelion/9595369280_dd88b61814.jpg
#   inflating: flowers/rose/5001848135_63300a26a8_n.jpg
#   inflating: flowers/dandelion/7099259755_1c66420206_n.jpg
#   inflating: flowers/rose/5001845289_e5740889b0_n.jpg
#   inflating: flowers/rose/8723767157_c45bfd3ab6.jpg
#   inflating: flowers/rose/8622493424_877ae35ed7.jpg
#   inflating: flowers/dandelion/921252114_91e334b950.jpg
#   inflating: flowers/dandelion/7132676187_7a4265b16f_n.jpg
#   inflating: flowers/rose/5335937199_2c83d46a57_n.jpg
#   inflating: flowers/rose/6473543547_4fefdbd5dc.jpg
#   inflating: flowers/dandelion/7196683612_6c4cf05b24.jpg
#   inflating: flowers/rose/5001852517_6a8713ffe2_n.jpg
#   inflating: flowers/dandelion/8717787983_c83bdf39fe_n.jpg
#   inflating: flowers/rose/5332550500_ab341aefd8.jpg
#   inflating: flowers/rose/8209458141_38f38be65c_m.jpg
#   inflating: flowers/rose/5001854803_cb87747d4a_n.jpg
#   inflating: flowers/dandelion/9818247_e2eac18894.jpg
#   inflating: flowers/rose/4979895172_ca06eba616.jpg
#   inflating: flowers/tulip/738207467_fc59cfcd9b_z.jpg
#   inflating: flowers/rose/8642943283_47e44d049d_m.jpg
#   inflating: flowers/tulip/9831362123_5aac525a99_n.jpg
#   inflating: flowers/dandelion/8681388520_c697dee897_n.jpg
#   inflating: flowers/rose/7470985338_a1f3bba601_n.jpg
#   inflating: flowers/rose/850416050_31b3ff7086.jpg
#   inflating: flowers/dandelion/9939430464_5f5861ebab.jpg
#   inflating: flowers/rose/5961803532_9368212949_m.jpg
#   inflating: flowers/rose/8035910225_125beceb98_n.jpg
#   inflating: flowers/rose/5001857777_440e725f2f_n.jpg
#   inflating: flowers/rose/7409458444_0bfc9a0682_n.jpg
#   inflating: flowers/dandelion/854593001_c57939125f_n.jpg
#   inflating: flowers/tulip/7166632158_666116d770_n.jpg
#   inflating: flowers/tulip/8768645961_8f1e097170_n.jpg
#   inflating: flowers/dandelion/9200211647_be34ce978b.jpg
#   inflating: flowers/tulip/8712267391_c756f18ee7_n.jpg
#   inflating: flowers/tulip/8713391394_4b679ea1e3_n.jpg
#   inflating: flowers/flowers/rose/4360743371_6238b36d8c_m.jpg
#   inflating: flowers/rose/7186509956_c37c02fb43_n.jpg
#   inflating: flowers/flowers/rose/388405293_4db1d71f21_n.jpg
#   inflating: flowers/dandelion/8194560480_bfc1fb5801.jpg
#   inflating: flowers/flowers/rose/5335946155_be70e11cf2_n.jpg
#   inflating: flowers/flowers/rose/3621011057_0d03bd171b_n.jpg
#   inflating: flowers/tulip/8585102511_fc452e6700_n.jpg
#   inflating: flowers/dandelion/7448453384_fb9caaa9af_n.jpg
#   inflating: flowers/flowers/rose/9300754115_dd79670066_n.jpg
#   inflating: flowers/tulip/8710148289_6fc196a0f8_n.jpg
#   inflating: flowers/tulip/9870557734_88eb3b9e3b_n.jpg
#   inflating: flowers/tulip/8758519201_16e8d2d781_n.jpg
#   inflating: flowers/flowers/rose/7481117422_66e73115ac_n.jpg
#   inflating: flowers/flowers/rose/8036594516_69a7da5f73_m.jpg
#   inflating: flowers/flowers/rose/4694341873_65fe187a4e_n.jpg
#   inflating: flowers/dandelion/7062171343_db61c92737_n.jpg
#   inflating: flowers/tulip/8713392604_90631fb809_n.jpg
#   inflating: flowers/flowers/rose/7420699022_60fa574524_m.jpg
#   inflating: flowers/tulip/8748266132_5298a91dcf_n.jpg
#   inflating: flowers/flowers/rose/8269247725_4b56cd860d_n.jpg
#   inflating: flowers/flowers/rose/5526964611_76ef13025c_n.jpg
#   inflating: flowers/flowers/rose/4918137796_21f0922b0c_n.jpg
#   inflating: flowers/flowers/rose/3634244527_e72c47842c_n.jpg
#   inflating: flowers/tulip/8759594528_2534c0ec65_n.jpg
#   inflating: flowers/flowers/rose/8524505682_bda885af3a_n.jpg
#   inflating: flowers/flowers/rose/4900231976_f8ced2b42a_n.jpg
#   inflating: flowers/tulip/7166612682_711e680027_n.jpg
#   inflating: flowers/tulip/6998661030_46cbb7892a.jpg
#   inflating: flowers/tulip/8713398614_88202e452e_n.jpg
#   inflating: flowers/flowers/rose/7481118556_6c209b9b7d_n.jpg
#   inflating: flowers/flowers/rose/7474124984_ca015e8c10_n.jpg
#   inflating: flowers/tulip/8713389178_66bceb71a8_n.jpg
#   inflating: flowers/flowers/rose/4644336779_acd973528c.jpg
#   inflating: flowers/flowers/daisy/6207492986_0ff91f3296.jpg
#   inflating: flowers/flowers/rose/4684127262_6c3346188d.jpg
#   inflating: flowers/flowers/rose/5002453464_ab2bcb3829_n.jpg
#   inflating: flowers/flowers/rose/4413509121_a62879598a.jpg
#   inflating: flowers/flowers/daisy/8619103877_d8c82c5f34_n.jpg
#   inflating: flowers/tulip/7003964080_4566470798_n.jpg
#   inflating: flowers/dandelion/8980460785_b5e6842e59_n.jpg
#   inflating: flowers/flowers/rose/8035910225_125beceb98_n.jpg
#   inflating: flowers/tulip/7166644048_b00a14f01b_n.jpg
#   inflating: flowers/flowers/daisy/4544110929_a7de65d65f_n.jpg
#   inflating: flowers/tulip/8586205446_8953a6c70e_n.jpg
#   inflating: flowers/flowers/rose/4495885281_fe2a3b671d.jpg
#   inflating: flowers/flowers/daisy/7630511450_02d3292e90.jpg
#   inflating: flowers/tulip/8677713853_1312f65e71.jpg
#   inflating: flowers/flowers/daisy/4890424315_6a59696357_n.jpg
#   inflating: flowers/flowers/daisy/6046940312_8faf552f3e_n.jpg
#   inflating: flowers/tulip/8668973377_c69527db42_m.jpg
#   inflating: flowers/flowers/daisy/3450822975_7e77d67636_n.jpg
#   inflating: flowers/tulip/8572847041_d0cc07861f_n.jpg
#   inflating: flowers/tulip/6958342976_a4a9483488_n.jpg
#   inflating: flowers/flowers/daisy/4613992315_143ccc2a10_m.jpg
#   inflating: flowers/flowers/daisy/5924910021_b6debeb7b5_n.jpg
#   inflating: flowers/flowers/rose/8437935944_aab997560a_n.jpg
#   inflating: flowers/tulip/8688502760_1c8d6de921_m.jpg
#   inflating: flowers/flowers/daisy/34522174462_b7cbee3ecb_n.jpg
#   inflating: flowers/flowers/daisy/3379332157_04724f6480.jpg
#   inflating: flowers/flowers/daisy/34520690871_8fe693bc71_n.jpg
#   inflating: flowers/flowers/daisy/8694909523_3ca25d449d_n.jpg
#   inflating: flowers/flowers/daisy/7454630692_ab2d67dd18_m.jpg
#   inflating: flowers/flowers/daisy/34591991761_16fc5c9c00_n.jpg
#   inflating: flowers/flowers/tulip/8817622133_a42bb90e38_n.jpg
#   inflating: flowers/flowers/rose/4764674741_82b8f93359_n.jpg
#   inflating: flowers/flowers/tulip/7179796338_05e8b1c87b.jpg
#   inflating: flowers/flowers/tulip/7046815693_f159e96acd_n.jpg
#   inflating: flowers/flowers/tulip/5700394524_dc6f8fa9cd_n.jpg
#   inflating: flowers/flowers/daisy/33879354664_615c72773d_n.jpg
#   inflating: flowers/flowers/daisy/3773181799_5def396456.jpg
#   inflating: flowers/flowers/dandelion/8689302100_be76a16ccc_n.jpg
#   inflating: flowers/flowers/dandelion/8738317694_eca2ce3bfc_n.jpg
#   inflating: flowers/flowers/tulip/6539831765_c21b68910e_n.jpg
#   inflating: flowers/flowers/daisy/7790614422_4557928ab9_n.jpg
#   inflating: flowers/flowers/dandelion/8963359346_65ca69c59d_n.jpg
#   inflating: flowers/flowers/tulip/7166616072_1233051d98_n.jpg
#   inflating: flowers/flowers/dandelion/9726260379_4e8ee66875_m.jpg
#   inflating: flowers/flowers/tulip/5718511304_9334269df2_n.jpg
#   inflating: flowers/flowers/daisy/3386988684_bc5a66005e.jpg
#   inflating: flowers/flowers/daisy/7538403124_f2fc48750a.jpg
#   inflating: flowers/flowers/tulip/5717951871_4af1b319eb_n.jpg
#   inflating: flowers/flowers/daisy/34652819496_0b6f758986_n.jpg
#   inflating: flowers/flowers/dandelion/8989067485_aab399460b_n.jpg
#   inflating: flowers/flowers/dandelion/8805314187_1aed702082_n.jpg
#   inflating: flowers/flowers/tulip/4624404489_11e10fcd33_n.jpg
# ...
#   inflating: flowers/tulip/8713407768_f880df361f.jpg
#   inflating: flowers/flowers/rose/5349861432_96137002c4_n.jpg
#   inflating: flowers/dandelion/14065420729_9b388bf7cb_m.jpg
#   inflating: flowers/dandelion/5572197407_a0047238a6.jpg
#   inflating: flowers/flowers/sunflower/9564240106_0577e919da_n.jpg
#   inflating: flowers/dandelion/19443726008_8c9c68efa7_m.jpg
#   inflating: flowers/daisy/5561775629_a2b709b3a4_n.jpg
#   inflating: flowers/daisy/34310869690_56cdc84a17_n.jpg
#   inflating: flowers/flowers/tulip/17720403638_94cfcd8d5c_n.jpg
#   inflating: flowers/tulip/8585103457_d64697c3cf_n.jpg
#   inflating: flowers/daisy/3337536080_1db19964fe.jpg
#   inflating: flowers/rose/11233672494_d8bf0a3dbf_n.jpg
#   inflating: flowers/daisy/34571214621_f655295459_n.jpg
#   inflating: flowers/flowers/tulip/14256494935_0ee69cfa03_n.jpg
#   inflating: flowers/flowers/rose/174109630_3c544b8a2f.jpg
#   inflating: flowers/flowers/sunflower/8481979626_98c9f88848_n.jpg
#   inflating: flowers/dandelion/14886963928_d4856f1eb6_n.jpg
#   inflating: flowers/tulip/6948277038_89d7ff42e2_m.jpg
#   inflating: flowers/flowers/rose/2550860627_998a4fc4c1.jpg
#   inflating: flowers/flowers/rose/4735314389_94fe1b2a9f_n.jpg
#   inflating: flowers/daisy/5896674046_a4879f718e_n.jpg
#   inflating: flowers/flowers/tulip/14238880681_2b86165b41_n.jpg
#   inflating: flowers/dandelion/3856725141_0db85f466d_n.jpg
#   inflating: flowers/flowers/tulip/14256111494_f9985585f5_n.jpg
#   inflating: flowers/flowers/sunflower/8014735546_3db46bb1fe_n.jpg
#   inflating: flowers/tulip/6994351792_343e18cbf6_n.jpg
#   inflating: flowers/flowers/tulip/2432389721_4d14971060_n.jpg
#   inflating: flowers/flowers/tulip/3523398585_376960a611_m.jpg
#   inflating: flowers/flowers/tulip/20282921225_6033da8cd5_n.jpg
#   inflating: flowers/flowers/sunflower/9610373748_b9cb67bd55.jpg
#   inflating: flowers/flowers/rose/2215318403_06eb99176a.jpg
#   inflating: flowers/dandelion/33904560113_497239a68f_n.jpg
#   inflating: flowers/flowers/rose/18741313803_1bbf842fc6_n.jpg
#   inflating: flowers/daisy/34520690871_8fe693bc71_n.jpg
#   inflating: flowers/daisy/4897587985_f9293ea1ed.jpg
#   inflating: flowers/daisy/33901756843_94e198d40e_n.jpg
#   inflating: flowers/dandelion/34725991045_05812dedd5_n.jpg
#   inflating: flowers/flowers/tulip/16862349256_0a1f91ab53.jpg
#   inflating: flowers/flowers/sunflower/9555824387_32b151e9b0_m.jpg
#   inflating: flowers/flowers/rose/2888138918_402096c7fb.jpg
#   inflating: flowers/flowers/tulip/14087792403_f34f37ba3b_m.jpg
#   inflating: flowers/tulip/8614237582_74417799f4_m.jpg
#   inflating: flowers/dandelion/4552591312_02fe1dcc04_n.jpg
#   inflating: flowers/tulip/8713398906_28e59a225a_n.jpg
#   inflating: flowers/flowers/rose/18584002386_cec0df537d_n.jpg
#   inflating: flowers/flowers/rose/5336546068_8fd643243c_n.jpg
#   inflating: flowers/daisy/3379332157_04724f6480.jpg
#   inflating: flowers/daisy/34695914906_961f92ffcd_n(1).jpg
#   inflating: flowers/flowers/tulip/14746916178_40403cc57e.jpg
#   inflating: flowers/flowers/sunflower/7176723954_e41618edc1_n.jpg
#   inflating: flowers/dandelion/3393564906_f2df184b76_n.jpg
#   inflating: flowers/flowers/sunflower/6606823367_e89dc52a95_n.jpg
#   inflating: flowers/tulip/7166620850_8a37b95972_n.jpg
#   inflating: flowers/daisy/33849854704_d2a2415e4d_n.jpg
#   inflating: flowers/flowers/tulip/20340696625_4095592e55_n.jpg
#   inflating: flowers/dandelion/33907694863_f7c0f23ef3_n.jpg
#   inflating: flowers/tulip/8659691170_09db83d023.jpg
#   inflating: flowers/daisy/4820415253_15bc3b6833_n.jpg
#   inflating: flowers/flowers/tulip/3396033831_bb88d93630.jpg
#   inflating: flowers/daisy/34342014230_4230ae8e08_n.jpg
#   inflating: flowers/flowers/tulip/14487705209_ea723109e1_m.jpg
#   inflating: flowers/flowers/tulip/3455026124_d66cafb9fc.jpg
#   inflating: flowers/flowers/tulip/2440874162_27a7030402_n.jpg
#   inflating: flowers/daisy/5876455546_32049e5585.jpg
#   inflating: flowers/tulip/8757486380_90952c5377.jpg
#   inflating: flowers/daisy/34542837641_10492bf600_n.jpg
#   inflating: flowers/flowers/tulip/38287568_627de6ca20.jpg
#   inflating: flowers/flowers/sunflower/9481563239_01b585b41d_n.jpg
#   inflating: flowers/tulip/7166539842_43b7e02883.jpg
#   inflating: flowers/flowers/rose/5001848135_63300a26a8_n.jpg
#   inflating: flowers/flowers/sunflower/8265023280_713f2c69d0_m.jpg
#   inflating: flowers/flowers/tulip/26685648806_c76dd583b9_n.jpg
#   inflating: flowers/flowers/tulip/3502615974_ef4bd13202_n.jpg
#   inflating: flowers/flowers/rose/6209630964_e8de48fe04_m.jpg
#   inflating: flowers/flowers/rose/5349248481_6445341842_n.jpg
#   inflating: flowers/dandelion/5003160931_cf8cbb846f.jpg
#   inflating: flowers/flowers/tulip/17545306218_5bf0ee38cd_n.jpg
#   inflating: flowers/flowers/tulip/16862351376_f0fcc6fc91_n.jpg
#   inflating: flowers/dandelion/4714026966_93846ddb74_m.jpg
#   inflating: flowers/flowers/tulip/14266093711_66d18a1e44_n.jpg
#   inflating: flowers/daisy/34295444880_b4376b3a8b_n.jpg
#   inflating: flowers/daisy/4613992315_143ccc2a10_m.jpg
#   inflating: flowers/daisy/34546791291_eb8e15e18a_n.jpg
#   inflating: flowers/dandelion/7015947703_11b30c20c9_n.jpg
#   inflating: flowers/dandelion/5727534342_419604c177_n.jpg
#   inflating: flowers/dandelion/2502627784_4486978bcf.jpg
#   inflating: flowers/dandelion/flickr.pyc
#   inflating: flowers/dandelion/2670304799_a3f2eef516_m.jpg
#   inflating: flowers/flowers/sunflower/7654774598_6b715a8d3e.jpg
#   inflating: flowers/flowers/tulip/20298145571_89ea244c38_n.jpg
#   inflating: flowers/flowers/sunflower/8014734302_65c6e83bb4_m.jpg
#   inflating: flowers/daisy/34643914016_2e659d6e82_n.jpg
#   inflating: flowers/dandelion/6983120596_8b9f084ac2_n.jpg
#   inflating: flowers/daisy/6299498346_b9774b6500.jpg
#   inflating: flowers/tulip/8711277462_b43df5454b_m.jpg
#   inflating: flowers/dandelion/3554992110_81d8c9b0bd_m.jpg
#   inflating: flowers/dandelion/8905148527_ba9f55cd78.jpg
#   inflating: flowers/flowers/tulip/17159349572_c0c51599f7_n.jpg
#   inflating: flowers/daisy/34518374242_310e7abd54_n.jpg
#   inflating: flowers/flowers/tulip/3614805920_7a6610aa4b_n.jpg
#   inflating: flowers/flowers/sunflower/9558627290_353a14ba0b_m.jpg
#   inflating: flowers/flowers/tulip/155097272_70feb13184.jpg
#   inflating: flowers/flowers/sunflower/9783416751_b2a03920f7_n.jpg
#   inflating: flowers/dandelion/34591866681_ff35af51df_n.jpg
#   inflating: flowers/flowers/sunflower/9240005603_6a9b71dcea_n.jpg
#   inflating: flowers/flowers/rose/5693486585_cf64d87519_n.jpg
#   inflating: flowers/flowers/tulip/4574785121_5d8ec4626e.jpg
#   inflating: flowers/flowers/tulip/142235914_5419ff8a4a.jpg
#   inflating: flowers/flowers/tulip/17159816388_deafbebdb0.jpg
#   inflating: flowers/dandelion/9617087594_ec2a9b16f6.jpg
#   inflating: flowers/flowers/tulip/3476945045_97ff41e8ec_n.jpg
#   inflating: flowers/flowers/tulip/16098264209_38fe491093.jpg
#   inflating: flowers/dandelion/3487229452_73e3004858.jpg
#   inflating: flowers/daisy/5058708968_8bdcd29e63_n.jpg
#   inflating: flowers/flowers/tulip/4521037085_70d5802e1d_m.jpg
#   inflating: flowers/flowers/tulip/21083449726_2895661dfb_n.jpg
#   inflating: flowers/dandelion/8083321316_f62ea76f72_n.jpg
#   inflating: flowers/dandelion/7218569994_de7045c0c0.jpg
#   inflating: flowers/flowers/tulip/3502685880_f026400dce_n.jpg
#   inflating: flowers/flowers/tulip/20711107885_98d96a705b_n.jpg
#   inflating: flowers/daisy/4923279674_e7f8e70794_n.jpg
#   inflating: flowers/flowers/rose/7820626638_3e2d712303.jpg
#   inflating: flowers/dandelion/8663932737_0a603ab718_n.jpg
#   inflating: flowers/daisy/5896680664_641de2de5a_n.jpg
#   inflating: flowers/dandelion/7083589767_2859993846_n.jpg
#   inflating: flowers/flowers/rose/8181940917_1ac63937d5_n.jpg
#   inflating: flowers/flowers/tulip/2294116183_a30d2aa2c1_m.jpg
#   inflating: flowers/dandelion/5862288632_1df5eb6dd0.jpg
#   inflating: flowers/dandelion/34692530906_fe2470a5e5_n.jpg
#   inflating: flowers/flowers/tulip/16568550940_d64ee7898f_n.jpg
#   inflating: flowers/dandelion/5607983792_f8b8766ff7.jpg
#   inflating: flowers/dandelion/2597655841_07fb2955a4.jpg
#   inflating: flowers/flowers/tulip/14861513337_4ef0bfa40d.jpg
#   inflating: flowers/flowers/tulip/18406629611_4d1edcf23b_n.jpg
#   inflating: flowers/flowers/tulip/16930105456_8b826dc4a8_n.jpg
#   inflating: flowers/dandelion/8980273068_cf7e8b880a_n.jpg
#   inflating: flowers/flowers/tulip/16265876844_0a149c4f76.jpg
#   inflating: flowers/dandelion/8632704230_ccafc5f7e2.jpg
#   inflating: flowers/flowers/tulip/16594995743_ce72c61201_n.jpg
#   inflating: flowers/flowers/rose/8209458141_38f38be65c_m.jpg
#   inflating: flowers/dandelion/7196409186_a59957ce0b_m.jpg
#   inflating: flowers/dandelion/8720503800_cab5c62a34.jpg
#   inflating: flowers/flowers/tulip/14278331403_4c475f9a9b.jpg
#   inflating: flowers/dandelion/7249354462_21925f7d95_n.jpg
#   inflating: flowers/dandelion/494108764_e00178af6e.jpg
#   inflating: flowers/flowers/tulip/14094146241_0b9fa7b3e0.jpg
#   inflating: flowers/dandelion/7295618968_c08a326cc1_m.jpg
#   inflating: flowers/dandelion/7367491658_9eb4dc2384_m.jpg
#   inflating: flowers/dandelion/6994938270_bf51d0fe63.jpg
#   inflating: flowers/dandelion/7132482331_01769e36e9_n.jpg
#   inflating: flowers/dandelion/7247192002_39b79998f0_n.jpg
#   inflating: flowers/dandelion/8979062599_86cac547b8.jpg
#   inflating: flowers/dandelion/8978962053_0727b41d26.jpg
#   inflating: flowers/dandelion/7843447416_847e6ba7f4_m.jpg
#   inflating: flowers/flowers/daisy/5896675418_e6ff20a739_n.jpg
#   inflating: flowers/dandelion/8831808134_315aedb37b.jpg
#   inflating: flowers/dandelion/7465850028_cdfaae235a_n.jpg
#   inflating: flowers/dandelion/8980164828_04fbf64f79_n.jpg
#   inflating: flowers/flowers/daisy/3275951182_d27921af97_n.jpg
#   inflating: flowers/flowers/daisy/33859244503_eeeca6a397_n.jpg
#   inflating: flowers/flowers/daisy/302782756_d35cb3e468.jpg
#   inflating: flowers/flowers/daisy/6054952060_c88612f3c5_n.jpg
#   inflating: flowers/flowers/daisy/3627678863_557552c879_m.jpg
#   inflating: flowers/flowers/daisy/29380234244_c50a60374e_n.jpg
#   inflating: flowers/flowers/daisy/2666572212_2caca8de9f_n.jpg
#   inflating: flowers/flowers/daisy/34546791291_eb8e15e18a_n.jpg
#   inflating: flowers/flowers/daisy/4565255237_9ba29c4d4e_n.jpg
#   inflating: flowers/flowers/daisy/286875003_f7c0e1882d.jpg
#   inflating: flowers/flowers/daisy/8740807508_0587f5b7b7.jpg
#   inflating: flowers/flowers/daisy/34287492780_6dab677857_n.jpg
#   inflating: flowers/flowers/daisy/3494265422_9dba8f2191_n.jpg
#   inflating: flowers/flowers/daisy/512177035_70afc925c8.jpg
#   inflating: flowers/flowers/daisy/34532930772_5cc5fc600d_n.jpg
#   inflating: flowers/flowers/daisy/3440366251_5b9bdf27c9_m.jpg
#   inflating: flowers/flowers/daisy/3633489595_a037a9b7a4_m.jpg
#   inflating: flowers/flowers/daisy/33891703033_822f7810ce_n.jpg
#   inflating: flowers/flowers/daisy/8983779970_9d3a6a3bf2_n.jpg
#   inflating: flowers/flowers/daisy/4746633946_23933c0810.jpg
#   inflating: flowers/flowers/rose/921984328_a60076f070_m.jpg
#   inflating: flowers/flowers/daisy/2713919471_301fcc941f.jpg
#   inflating: flowers/flowers/daisy/6323721068_3d3394af6d_n.jpg
#   inflating: flowers/flowers/daisy/4222584034_8964cbd3de.jpg
#   inflating: flowers/flowers/rose/5086249859_d066b37b8a_m.jpg
#   inflating: flowers/flowers/rose/534228982_4afbcece9b_m.jpg
#   inflating: flowers/flowers/rose/685724528_6cd5cbe203.jpg
#   inflating: flowers/flowers/rose/7316409504_7cf3707f8a_m.jpg
#   inflating: flowers/flowers/daisy/5883162120_dc7274af76_n.jpg
#   inflating: flowers/flowers/rose/5212885371_fe27c406a2_n.jpg
#   inflating: flowers/flowers/rose/4654893119_45d232016b.jpg
#   inflating: flowers/flowers/rose/8301512319_45185c447f_n.jpg
#   inflating: flowers/flowers/rose/5398569540_7d134c42cb_n.jpg
#   inflating: flowers/flowers/rose/7683456068_02644b8382_m.jpg
#   inflating: flowers/flowers/rose/5349860036_389d912fb7_n.jpg
#   inflating: flowers/flowers/rose/3751835302_d5a03f55e8_n.jpg
#   inflating: flowers/flowers/rose/3742155164_14b557a51c_n.jpg
#   inflating: flowers/flowers/rose/394990940_7af082cf8d_n.jpg
#   inflating: flowers/flowers/rose/4612766755_7d3f047db0_n.jpg
#   inflating: flowers/flowers/rose/475936554_a2b38aaa8e.jpg
#   inflating: flowers/flowers/rose/7304710956_015b41f802_m.jpg
#   inflating: flowers/flowers/rose/8241471746_5d81fdd3c0_n.jpg
#   inflating: flowers/flowers/rose/5002448396_7ca4d44086_n.jpg
#   inflating: flowers/flowers/rose/7456196174_f9de97ba73_n.jpg
#   inflating: flowers/flowers/rose/5336562212_d014ddf9ca_n.jpg
#   inflating: flowers/flowers/dandelion/8757650550_113d7af3bd.jpg
#   inflating: flowers/flowers/dandelion/8701999625_8d83138124.jpg
#   inflating: flowers/flowers/dandelion/8723679596_391a724d4f_m.jpg
#   inflating: flowers/flowers/dandelion/8719388716_1a392c4c0e_n.jpg
#   inflating: flowers/flowers/dandelion/8980145452_efbd6e3b04.jpg
#   inflating: flowers/flowers/dandelion/8739657154_6db14796c9.jpg
#   inflating: flowers/flowers/dandelion/8979062599_86cac547b8.jpg
#   inflating: flowers/flowers/dandelion/run_me.py
#   inflating: flowers/flowers/rose/9164900485_605aa12da8.jpg
#   inflating: flowers/flowers/dandelion/8647874151_aac8db2588_m.jpg
#   inflating: flowers/flowers/rose/7376471712_e1be793f94.jpg
#   inflating: flowers/flowers/rose/5001855689_e07486c44d_n.jpg
#   inflating: flowers/flowers/rose/7456439862_8b1ae909b7_n.jpg
#   inflating: flowers/flowers/dandelion/9818247_e2eac18894.jpg
#   inflating: flowers/flowers/dandelion/510874382_f7e3435043.jpg
#   inflating: flowers/flowers/dandelion/7218569994_de7045c0c0.jpg
#   inflating: flowers/flowers/dandelion/4514343281_26781484df.jpg
#   inflating: flowers/flowers/dandelion/5605093210_5fecb71c61.jpg
#   inflating: flowers/flowers/dandelion/4258272381_65bd4b8191_m.jpg
#   inflating: flowers/flowers/dandelion/34562659841_caba988a0c_n.jpg
#   inflating: flowers/flowers/dandelion/3954167682_128398bf79_m.jpg
#   inflating: flowers/flowers/dandelion/8220011556_28e0cab67f.jpg
#   inflating: flowers/flowers/dandelion/33856267954_b806fab0db_n.jpg
#   inflating: flowers/flowers/dandelion/3998927705_af499a4f29.jpg
#   inflating: flowers/flowers/dandelion/451965300_619b781dc9_m.jpg
#   inflating: flowers/tulip/8729501081_b993185542_m.jpg
#   inflating: flowers/tulip/8712263493_3db76c5f82.jpg
#   inflating: flowers/flowers/dandelion/34721329895_529f999fb6_n.jpg
#   inflating: flowers/flowers/dandelion/3372748508_e5a4eacfcb_n.jpg
#   inflating: flowers/tulip/7166554924_432aaae4b2_n.jpg
#   inflating: flowers/tulip/8838347159_746d14e6c1_m.jpg
#   inflating: flowers/flowers/dandelion/4598938531_9749b3b56a.jpg
#   inflating: flowers/tulip/9947385346_3a8cacea02_n.jpg
#   inflating: flowers/tulip/8511683706_4173683d45_m.jpg
#   inflating: flowers/flowers/dandelion/3761310831_41b5eba622_n.jpg
#   inflating: flowers/tulip/8697784345_e75913d220.jpg
#   inflating: flowers/tulip/6982913043_3b873c6a25.jpg
#   inflating: flowers/tulip/7481204112_e3c57dd40a_n.jpg
#   inflating: flowers/tulip/7166552648_28b6dce578_n.jpg
#   inflating: flowers/tulip/8702982836_75222725d7.jpg
#   inflating: flowers/tulip/9048307967_40a164a459_m.jpg
#   inflating: flowers/tulip/8717900362_2aa508e9e5.jpg
#   inflating: flowers/tulip/9947374414_fdf1d0861c_n.jpg
#   inflating: flowers/tulip/7205698252_b972087cc2.jpg
#   inflating: flowers/tulip/7166574936_3d93a510c5_n.jpg
#   inflating: flowers/tulip/8758464923_75a5ffe320_n.jpg
#   inflating: flowers/tulip/8622237974_b362574785_n.jpg
#   inflating: flowers/tulip/8838914676_8ef4db7f50_n.jpg
#   inflating: flowers/tulip/7447655334_e8f805ab95_m.jpg
#   inflating: flowers/tulip/9019694597_2d3bbedb17.jpg
#   inflating: flowers/tulip/7448453762_aea8739f1b.jpg
#   inflating: flowers/tulip/8603340662_0779bd87fd.jpg
#   inflating: flowers/tulip/8690789564_394eb04982_n.jpg
#   inflating: flowers/tulip/9976515506_d496c5e72c.jpg

# %%
from skimage import io
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
# function to plot n images using subplots
def plot_image(images, captions=None, cmap=None ):
    f, axes = plt.subplots(1, len(images), sharey=True)
    f.set_figwidth(15)
    for ax,image in zip(axes, images):
        ax.imshow(image, cmap)

# %% [markdown]
# ##  Image Augmentation & Preprocessing
#
# In the following section, we'll look at some common image preprocessing techniques.

# %% [markdown]
# ### Understanding images and channels
#
# As these images are RGB images they would constitute three channels - one for each of the color channels

# %%
# path to your dataset
DATASET_PATH = './flowers'
flowers_cls = ['daisy', 'rose']

# %% [markdown]
# We'll now use the `glob` module of python to <a href="https://en.wikipedia.org/wiki/Glob_(programming)">glob</a> through the directory where the data is stored, i.e. to walk through the directory, subdirectories and the files. It uses regular expressions to access files having names matching some pattern. In our case, we want to access all the files in the path `flowers/rose/` and `flowers/daisy/`, so we'll just use the regex `*` (used as a 'wildcard' to catch everything).
#
# An example of how the glob module works is given below - you first join the base directory path with the subdirectory (e.g. `flowers/rose/`) and then `glob` through it to access all the individual files (images here).

# %%
# globbing example
# help(glob)
flower_path = os.path.join(DATASET_PATH, flowers_cls[1], '*')
print(flower_path)

# glob through the directory (returns a list of all file paths)
flower_path = glob.glob(flower_path)
print(flower_path[3]) # access an individual file
# Out:
# ./flowers/rose/*
# ./flowers/rose/9458445402_79e4dfa89c.jpg

# %%
# run this block multiple times to look at some randomly chosen images of roses
rand_index = random.randint(0, len(flower_path))
image = io.imread(flower_path[rand_index])
plt.imshow(image)

# %%
# plot a sample image
flower_path = os.path.join(DATASET_PATH, flowers_cls[1], '*')
flower_path = glob.glob(flower_path)

# access some element (a file) from the list
image = io.imread(flower_path[729])
plt.imshow(image)

# %%
print(image.shape)
# Out:
# (240, 163, 3)

# %%
# plotting the original image and the RGB channels
f, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, sharey=True)
f.set_figwidth(15)
ax1.imshow(image)

# RGB channels
ax2.imshow(image[:, : , 0])
ax3.imshow(image[:, : , 1])
ax4.imshow(image[:, : , 2])
f.suptitle('Different Channels of Image')
# Out:
# Text(0.5, 0.98, 'Different Channels of Image')

# %% [markdown]
# ## Morphological Transformations

# %% [markdown]
# ### Thresholding
#
# One of the simpler operations where we take all the pixels whose intensities are above a certain threshold, and convert them to ones; the pixels having value less than the threshold are converted to zero. This results in a *binary image*.

# %%
# bin_image will be a (240, 320) True/False array
bin_image = image[:, :, 0] > 125
plot_image([image, bin_image], cmap='gray')

# %% [markdown]
# ### Erosion, Dilation, Opening & Closing

# %% [markdown]
# **Erosion** shrinks bright regions and enlarges dark regions. **Dilation** on the other hand is exact opposite side - it shrinks dark regions and enlarges the bright regions.
#
# **Opening** is erosion followed by dilation. Opening can remove small bright spots (i.e. “salt”) and connect small dark cracks. This tends to “open” up (dark) gaps between (bright) features.
#
# **Closing** is dilation followed by erosion. Closing can remove small dark spots (i.e. “pepper”) and connect small bright cracks. This tends to “close” up (dark) gaps between (bright) features.
#
# All these can be done using the `skimage.morphology` module. The basic idea is to have a **circular disk** of a certain size (3 below) move around the image and apply these transformations using it.

# %%
from skimage.morphology import binary_closing, binary_dilation, binary_erosion, binary_opening
from skimage.morphology import selem

# use a disk of radius 3
selem = selem.disk(3)

# oprning and closing
open_img = binary_opening(bin_image, selem)
close_img = binary_closing(bin_image, selem)

# erosion and dilation
eroded_img = binary_erosion(bin_image, selem)
dilated_img = binary_dilation(bin_image, selem)

plot_image([bin_image, open_img, close_img, eroded_img, dilated_img], cmap='gray')

# %% [markdown]
# ## Normalisation

# %% [markdown]
# Normalisation is the most crucial step in the pre-processing part. There are multiple ways to normalise images which we will be talking about.

# %%
norm1_image = image/255
norm2_image = (image - np.min(image))/(np.max(image) - np.min(image))
norm3_image = (image - np.percentile(image,5))/ (np.percentile(image,95) - np.percentile(image,5))

plot_image([image, norm1_image, norm2_image, norm3_image], cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Augmentations

# %% [markdown]
# There are multiple types of augmentations possible. The basic ones transform the original image using one of the following types of transformations:
#
# 1. Linear transformations
# 2. Affine transformations

# %%
from skimage import transform

# flip left-right, up-down
image_flipr = np.fliplr(image)
image_flipud = np.flipud(image)

plot_image([image, image_flipr, image_flipud])

# %%
# specify x and y coordinates to be used for shifting (mid points)
shift_x, shift_y = image.shape[0]/2, image.shape[1]/2

# translation by certain units
matrix_to_topleft = transform.SimilarityTransform(translation=[-shift_x, -shift_y])
matrix_to_center = transform.SimilarityTransform(translation=[shift_x, shift_y])

# rotation
rot_transforms =  transform.AffineTransform(rotation=np.deg2rad(45))
rot_matrix = matrix_to_topleft + rot_transforms + matrix_to_center
rot_image = transform.warp(image, rot_matrix)

# scaling 
scale_transforms = transform.AffineTransform(scale=(2, 2))
scale_matrix = matrix_to_topleft + scale_transforms + matrix_to_center
scale_image_zoom_out = transform.warp(image, scale_matrix)

scale_transforms = transform.AffineTransform(scale=(0.5, 0.5))
scale_matrix = matrix_to_topleft + scale_transforms + matrix_to_center
scale_image_zoom_in = transform.warp(image, scale_matrix)

# translation
transaltion_transforms = transform.AffineTransform(translation=(50, 50))
translated_image = transform.warp(image, transaltion_transforms)


plot_image([image, rot_image, scale_image_zoom_out, scale_image_zoom_in, translated_image])

# %%
# shear transforms
shear_transforms = transform.AffineTransform(shear=np.deg2rad(45))
shear_matrix = matrix_to_topleft + shear_transforms + matrix_to_center
shear_image = transform.warp(image, shear_matrix)

bright_jitter = image*0.999 + np.zeros_like(image)*0.001

plot_image([image, shear_image, bright_jitter])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# <hr>

# %% [markdown]
# # Network Building
#
# Let's now build the network. We'll import the resnet architecture from the module `resnet.py`.

# %%
import resnet

# specify image size and channels
img_channels = 3
img_rows = 100
img_cols = 100

# number of classes
nb_classes = 2

# %% [markdown]
# ### Data Generator ###
#
# Let's now set up the **data generator**. The code below sets up a custom data generator which is slightly different than <a href="https://keras.io/preprocessing/image/">the one that comes with the keras API</a>. The reason to use a custom generator is to be able to modify it according to the problem at hand (customizability).
#
#
# We won't be going through the entire code step-by-step in the lectures, though the code is explained below.
#
# To start with, we have the training data stored in $n$ directories (if there are $n$ classes). For a given batch size, we want to generate batches of data points and feed them to the model.
#
#
# The first `for` loop 'globs' through each of the classes (directories). For each class, it stores the path of each image in the list `paths`. In training mode, it subsets `paths` to contain the first 80% images; in validation mode it subsets the last 20%. In the special case of an ablation experiment, it simply subsets the first `ablation` images of each class.
#
# We store the paths of all the images (of all classes) in a combined list `self.list_IDs`. The dictionary `self.labels` contains the labels (as key:value pairs of `path: class_number (0/1)`).
#
# After the loop, we call the method `on_epoch_end()`, which creates an array `self.indexes` of length `self.list_IDs` and shuffles them (to shuffle all the data points at the end of each epoch).
#
# The `_getitem_` method uses the (shuffled) array `self.indexes` to select a `batch_size` number of entries (paths) from the path list `self.list_IDs`.
#
# Finally, the method `__data_generation` returns the batch of images as the pair X, y where X is of shape `(batch_size, height, width, channels)` and y is of shape `(batch size, )`. Note that `__data_generation` also does some preprocessing - it normalises the images (divides by 255) and crops the center 100 x 100 portion of the image. Thus, each image has the shape `(100, 100, num_channels)`. If any dimension (height or width) of an image less than 100 pixels, that image is deleted.

# %%
import numpy as np
import tensorflow as tf

class DataGenerator(tf.keras.utils.Sequence):
    'Generates data for Keras'
    
    def __init__(self, mode='train', ablation=None, flowers_cls=['daisy', 'rose'], 
                 batch_size=32, dim=(100, 100), n_channels=3, shuffle=True):
        """
        Initialise the data generator
        """
        self.dim = dim
        self.batch_size = batch_size
        self.labels = {}
        self.list_IDs = []
        
        # glob through directory of each class 
        for i, cls in enumerate(flowers_cls):
            paths = glob.glob(os.path.join(DATASET_PATH, cls, '*'))
            brk_point = int(len(paths)*0.8)
            if mode == 'train':
                paths = paths[:brk_point]
            else:
                paths = paths[brk_point:]
            if ablation is not None:
                paths = paths[:ablation]
            self.list_IDs += paths
            self.labels.update({p:i for p in paths})
            
        self.n_channels = n_channels
        self.n_classes = len(flowers_cls)
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(list_IDs_temp)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.empty((self.batch_size, *self.dim, self.n_channels))
        y = np.empty((self.batch_size), dtype=int)
        
        delete_rows = []

        # Generate data
        for i, ID in enumerate(list_IDs_temp):
            # Store sample
            img = io.imread(ID)
            img = img/255
            if img.shape[0] > 100 and img.shape[1] > 100:
                h, w, _ = img.shape
                img = img[int(h/2)-50:int(h/2)+50, int(w/2)-50:int(w/2)+50, : ]
            else:
                delete_rows.append(i)
                continue
            
            X[i,] = img
          
            # Store class
            y[i] = self.labels[ID]
        
        X = np.delete(X, delete_rows, axis=0)
        y = np.delete(y, delete_rows, axis=0)
        return X, tf.keras.utils.to_categorical(y, num_classes=self.n_classes)

# %% [markdown]
# ### Running Ablation Experiments
#
# Before training the net on the entire dataset, you should always try to first run some experiments to check whether the net is fitting on a small dataset or not.

# %% [markdown]
# #### Checking that the network is 'working'
#
# The first part of building a network is to get it to run on your dataset. Let's try fitting the net on only a few images and just one epoch. Note that since `ablation=100` is specified, 100 images of each class are used, so total number of batches is `np.floor(200/32)` = 6.
#
# Note that the `DataGenerator`  class 'inherits' from the `tf.keras.utils.Sequence` class, so it has all the functionalities of the base `tf.keras.utils.Sequence` class (such as the `model.fit_generator` method).

# %%
# using resnet 18
model = resnet.ResnetBuilder.build_resnet_18((img_channels, img_rows, img_cols), nb_classes)
model.compile(loss='categorical_crossentropy', optimizer='SGD',
              metrics=['accuracy'])

# create data generator objects in train and val mode
# specify ablation=number of data points to train on
training_generator = DataGenerator('train', ablation=100)
validation_generator = DataGenerator('val', ablation=100)

# fit: this will fit the net on 'ablation' samples, only 1 epoch
model.fit(training_generator, epochs=1, validation_data=validation_generator)
# Out:
# 6/6 [==============================] - 2s 409ms/step - loss: 1.6571 - accuracy: 0.5417 - val_loss: 3.2856 - val_accuracy: 0.4948

# %% [markdown]
# ### Overfitting on the Training Data
#
# Let's now perform another important step which should be done before training the full-fledged model-  trying to **deliberately overfit the model** on a small dataset.
#
# We'll use ablation=100 (i.e. training on 100 images of each class), so it is still a very small dataset, and we will use 20 epochs. In each epoch, 200/32=6 batches will be used.

# %%
# resnet 18
model = resnet.ResnetBuilder.build_resnet_18((img_channels, img_rows, img_cols), nb_classes)
model.compile(loss='categorical_crossentropy',optimizer='SGD',
              metrics=['accuracy'])

# generators
training_generator = DataGenerator('train', ablation=100)
validation_generator = DataGenerator('val', ablation=100)

# fit
model.fit(training_generator, epochs=20, validation_data=validation_generator)
# Out:
# Epoch 1/20
# 6/6 [==============================] - 2s 322ms/step - loss: 1.6945 - accuracy: 0.4948 - val_loss: 6.1287 - val_accuracy: 0.4948
# Epoch 2/20
# 6/6 [==============================] - 1s 226ms/step - loss: 1.5783 - accuracy: 0.7031 - val_loss: 4.5212 - val_accuracy: 0.5000
# Epoch 3/20
# 6/6 [==============================] - 1s 234ms/step - loss: 1.5181 - accuracy: 0.7760 - val_loss: 3.8250 - val_accuracy: 0.5000
# Epoch 4/20
# 6/6 [==============================] - 1s 245ms/step - loss: 1.4721 - accuracy: 0.7917 - val_loss: 3.3289 - val_accuracy: 0.4896
# Epoch 5/20
# 6/6 [==============================] - 1s 249ms/step - loss: 1.4258 - accuracy: 0.8125 - val_loss: 2.7786 - val_accuracy: 0.5000
# Epoch 6/20
# 6/6 [==============================] - 2s 254ms/step - loss: 1.4045 - accuracy: 0.8177 - val_loss: 2.3599 - val_accuracy: 0.5260
# Epoch 7/20
# 6/6 [==============================] - 1s 248ms/step - loss: 1.3821 - accuracy: 0.8646 - val_loss: 2.0113 - val_accuracy: 0.5469
# Epoch 8/20
# 6/6 [==============================] - 1s 248ms/step - loss: 1.3741 - accuracy: 0.8542 - val_loss: 1.8922 - val_accuracy: 0.5885
# Epoch 9/20
# 6/6 [==============================] - 2s 251ms/step - loss: 1.3527 - accuracy: 0.8490 - val_loss: 1.7102 - val_accuracy: 0.6510
# Epoch 10/20
# 6/6 [==============================] - 1s 248ms/step - loss: 1.3318 - accuracy: 0.8750 - val_loss: 1.6403 - val_accuracy: 0.6823
# Epoch 11/20
# 6/6 [==============================] - 2s 261ms/step - loss: 1.3366 - accuracy: 0.8594 - val_loss: 1.6073 - val_accuracy: 0.6875
# Epoch 12/20
# 6/6 [==============================] - 2s 256ms/step - loss: 1.3211 - accuracy: 0.8594 - val_loss: 1.5554 - val_accuracy: 0.6823
# Epoch 13/20
# 6/6 [==============================] - 1s 231ms/step - loss: 1.2764 - accuracy: 0.9010 - val_loss: 1.5109 - val_accuracy: 0.6927
# Epoch 14/20
# 6/6 [==============================] - 1s 225ms/step - loss: 1.2673 - accuracy: 0.9062 - val_loss: 1.4741 - val_accuracy: 0.7292
# Epoch 15/20
# 6/6 [==============================] - 1s 242ms/step - loss: 1.2604 - accuracy: 0.9010 - val_loss: 1.4623 - val_accuracy: 0.7344
# Epoch 16/20
# 6/6 [==============================] - 1s 232ms/step - loss: 1.2483 - accuracy: 0.9167 - val_loss: 1.4493 - val_accuracy: 0.7344
# Epoch 17/20
# 6/6 [==============================] - 1s 225ms/step - loss: 1.2304 - accuracy: 0.9167 - val_loss: 1.4338 - val_accuracy: 0.7396
# Epoch 18/20
# 6/6 [==============================] - 1s 229ms/step - loss: 1.2527 - accuracy: 0.8958 - val_loss: 1.4103 - val_accuracy: 0.7708
# Epoch 19/20
# 6/6 [==============================] - 1s 233ms/step - loss: 1.2275 - accuracy: 0.9167 - val_loss: 1.4105 - val_accuracy: 0.7656
# Epoch 20/20
# 6/6 [==============================] - 1s 250ms/step - loss: 1.2584 - accuracy: 0.8906 - val_loss: 1.3982 - val_accuracy: 0.7969

# %% [markdown]
# The results show that the training accuracy increases consistently with each epoch. The validation accuracy also increases and then plateaus out - this is a sign of 'good fit', i.e. we know that the model is at least able to learn from a small dataset, so we can hope that it will be able to learn from the entire set as well.

# %% [markdown]
# ### Hyperparameter Tuning
#
# First let's make a list the hyper-parameters we want to tune:
#
# 1. Learning Rate & Variation + Optimisers
# 2. Augmentation Techniques
#
# The basic idea is to track the validation loss with increasing epochs for various values of a hyperparameter.
#
# #### Keras Callbacks ####
#
# Before you move ahead, let's discuss a bit about **callbacks**. Callbacks are basically actions that you want to perform at specific instances of training. For example, we want to perform the action of storing the loss at the end of every epoch (the instance here is the end of an epoch).
#
#
# Formally, a callback is simply a function (if you want to perform a single action), or a list of functions (if you want to perform multiple actions), which are to be executed at specific events (end of an epoch, start of every batch, when the accuracy plateaus out, etc.). Keras provides some very useful callback functionalities through the class `tf.keras.callbacks.Callback`.
#
# Keras has many builtin callbacks (<a href="https://keras.io/callbacks/">listed here</a>). The generic way to **create a custom callback in keras** is:

# %%
# generic way to create custom callback
class LossHistory(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_batch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))

# %% [markdown]
# In the code below, we have created a custom callback to append the loss to a list at the end of every epoch. Note that `logs` is an attribute (a dictionary) of `tf.keras.callbacks.Callback`, and we are using it to get the value of the key 'loss'. Some other keys of this dict are `acc`, `val_loss` etc.
#
# To tell the model that we want to use a callback, we create an object of `LossHistory` called `history` and pass it to `model.fit_generator` using `callbacks=[history]`. In this case, we only have one callback `history`, though you can pass multiple callback objects through this list (an example of multiple callbacks is in the section below - see the code block of `DecayLR()`).
#
# We highly recommend you to <a href="https://keras.io/callbacks/">read the documentation of keras callbacks here</a>. For a gentler introduction to callbacks, you can read this <a href="https://machinelearningmastery.com/check-point-deep-learning-models-keras/"> nice blog post by Jason Brownlee.</a>

# %%
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import *

# range of learning rates to tune
hyper_parameters_for_lr = [0.1, 0.01, 0.001]

# callback to append loss
class LossHistory(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_epoch_end(self, epoch, logs={}):
        self.losses.append(logs.get('loss'))

# instantiate a LossHistory() object to store histories
history = LossHistory()
plot_data = {}

# for each hyperparam: train the model and plot loss history
for lr in hyper_parameters_for_lr:
    print ('\n\n'+'=='*20 + '   Checking for LR={}  '.format(lr) + '=='*20 )
    sgd = optimizers.SGD(lr=lr, clipnorm=1.)
    
    # model and generators
    model = resnet.ResnetBuilder.build_resnet_18((img_channels, img_rows, img_cols), nb_classes)
    model.compile(loss='categorical_crossentropy',optimizer= sgd,
                  metrics=['accuracy'])
    training_generator = DataGenerator('train', ablation=100)
    validation_generator = DataGenerator('val', ablation=100)
    model.fit(training_generator, epochs=3, validation_data=validation_generator, callbacks=[history])
    
    # plot loss history
    plot_data[lr] = history.losses
# Out:
# ========================================   Checking for LR=0.1  ========================================
# Epoch 1/3
# 6/6 [==============================] - 2s 337ms/step - loss: 1.5180 - accuracy: 0.7188 - val_loss: 12.9973 - val_accuracy: 0.5000
# Epoch 2/3
# 6/6 [==============================] - 1s 240ms/step - loss: 1.3664 - accuracy: 0.8073 - val_loss: 9.2475 - val_accuracy: 0.5052
# Epoch 3/3
# 6/6 [==============================] - 1s 224ms/step - loss: 1.2889 - accuracy: 0.8385 - val_loss: 4.0341 - val_accuracy: 0.5417
#
#
# ========================================   Checking for LR=0.01  ========================================
# Epoch 1/3
# 6/6 [==============================] - 2s 296ms/step - loss: 1.6999 - accuracy: 0.5260 - val_loss: 2.1048 - val_accuracy: 0.5729
# Epoch 2/3
# 6/6 [==============================] - 1s 233ms/step - loss: 1.5557 - accuracy: 0.6719 - val_loss: 1.6788 - val_accuracy: 0.6719
# Epoch 3/3
# 6/6 [==============================] - 2s 256ms/step - loss: 1.4805 - accuracy: 0.7604 - val_loss: 1.7388 - val_accuracy: 0.6719
#
#
# ========================================   Checking for LR=0.001  ========================================
# Epoch 1/3
# 6/6 [==============================] - 2s 326ms/step - loss: 1.7182 - accuracy: 0.4323 - val_loss: 4.0536 - val_accuracy: 0.5104
# Epoch 2/3
# 6/6 [==============================] - 1s 235ms/step - loss: 1.7043 - accuracy: 0.4479 - val_loss: 2.5179 - val_accuracy: 0.4896
# Epoch 3/3
# 6/6 [==============================] - 1s 238ms/step - loss: 1.6689 - accuracy: 0.5365 - val_loss: 1.8794 - val_accuracy: 0.5208

# %%
# plot loss history for each value of hyperparameter
f, axes = plt.subplots(1, 3, sharey=True)
f.set_figwidth(15)

plt.setp(axes, xticks=np.arange(0, len(plot_data[0.01]), 1)+1)

for i, lr in enumerate(plot_data.keys()):
    axes[i].plot(np.arange(len(plot_data[lr]))+1, plot_data[lr])

# %% [markdown]
# The results above show that a learning rate of 0.1 is the best, though using such a high learning rate for the entire training is usually not a good idea. Thus, we should use **learning rate decay** - starting from a high learning rate and decaying it with every epoch.
#
# We use another **custom callback** (`DecayLR`) to decay the learning rate at the end of every epoch. The decay rate is specified as 0.5 ^ epoch. Also, note that this time we are telling the model to **use two callbacks** (passed as a list `callbacks=[history, decay]` to `model.fit_generator`).
#
#
# Although we have used out own custom decay implementation here, you can use the ones built into <a href="https://keras.io/optimizers/">keras optimisers</a> (using the `decay` argument).

# %%
# learning rate decay
class DecayLR(tf.keras.callbacks.Callback):
    def __init__(self, base_lr=0.001, decay_epoch=1):
        super(DecayLR, self).__init__()
        self.base_lr = base_lr
        self.decay_epoch = decay_epoch 
        self.lr_history = []
        
    # set lr on_train_begin
    def on_train_begin(self, logs={}):
        tf.keras.backend.set_value(self.model.optimizer.lr, self.base_lr)

    # change learning rate at the end of epoch
    def on_epoch_end(self, epoch, logs={}):
        new_lr = self.base_lr * (0.5 ** (epoch // self.decay_epoch))
        self.lr_history.append(tf.keras.backend.get_value(self.model.optimizer.lr))
        tf.keras.backend.set_value(self.model.optimizer.lr, new_lr)

# to store loss history
history = LossHistory()
plot_data = {}

# start with lr=0.1
decay = DecayLR(base_lr=0.1)

# model
sgd = optimizers.SGD()
model = resnet.ResnetBuilder.build_resnet_18((img_channels, img_rows, img_cols), nb_classes)
model.compile(loss='categorical_crossentropy',optimizer= sgd,
              metrics=['accuracy'])
training_generator = DataGenerator('train', ablation=100)
validation_generator = DataGenerator('val', ablation=100)

model.fit(training_generator, epochs=3, validation_data=validation_generator, callbacks=[history, decay])

plot_data[lr] = decay.lr_history
# Out:
# Epoch 1/3
# 6/6 [==============================] - 2s 330ms/step - loss: 1.9638 - accuracy: 0.5990 - val_loss: 14.7930 - val_accuracy: 0.4896
# Epoch 2/3
# 6/6 [==============================] - 1s 249ms/step - loss: 1.4227 - accuracy: 0.7812 - val_loss: 4.4642 - val_accuracy: 0.5938
# Epoch 3/3
# 6/6 [==============================] - 1s 244ms/step - loss: 1.2271 - accuracy: 0.9010 - val_loss: 3.0117 - val_accuracy: 0.6406

# %%
plt.plot(np.arange(len(decay.lr_history)), decay.lr_history)

# %% [markdown]
# ## Augmentation Techniques
#
# Let's now write some code to implement data augmentation. Augmentation is usually done with data generators, i.e. the augmented data is generated batch-wise, on the fly.
#
# You can either use the built-in keras `ImageDataGenerator` or write your own data generator (for some custom features etc if you want). The two cells below show how to implement these respectively.

# %%
# keras data generator
# help(ImageDataGenerator)

from tensorflow.keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)

# %% [markdown]
# If you want to implement your own customized data generator (with augmentation), you can add the augmentation step easily to the `DataGenerator` class created above. The only change is that we stack the augmented images to the X, y arrays (as done in the last section of the code below).

# %%
import numpy as np
import tensorflow as tf

# data generator with augmentation
class AugmentedDataGenerator(tf.keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, mode='train', ablation=None, flowers_cls=['daisy', 'rose'], 
                 batch_size=32, dim=(100, 100), n_channels=3, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.labels = {}
        self.list_IDs = []
        self.mode = mode
        
        for i, cls in enumerate(flowers_cls):
            paths = glob.glob(os.path.join(DATASET_PATH, cls, '*'))
            brk_point = int(len(paths)*0.8)
            if self.mode == 'train':
                paths = paths[:brk_point]
            else:
                paths = paths[brk_point:]
            if ablation is not None:
                paths = paths[:ablation]
            self.list_IDs += paths
            self.labels.update({p:i for p in paths})
        
            
        self.n_channels = n_channels
        self.n_classes = len(flowers_cls)
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(list_IDs_temp)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.empty((self.batch_size, *self.dim, self.n_channels))
        y = np.empty((self.batch_size), dtype=int)
        
        delete_rows = []

        # Generate data
        for i, ID in enumerate(list_IDs_temp):
            # Store sample
            img = io.imread(ID)
            img = img/255
            if img.shape[0] > 100 and img.shape[1] > 100:
                h, w, _ = img.shape
                img = img[int(h/2)-50:int(h/2)+50, int(w/2)-50:int(w/2)+50, : ]
            else:
                delete_rows.append(i)
                continue
            
            X[i,] = img
          
            # Store class
            y[i] = self.labels[ID]
        
        X = np.delete(X, delete_rows, axis=0)
        y = np.delete(y, delete_rows, axis=0)
        
        # data augmentation
        if self.mode == 'train':
            aug_x = np.stack([datagen.random_transform(img) for img in X])
            X = np.concatenate([X, aug_x])
            y = np.concatenate([y, y])
        return X, tf.keras.utils.to_categorical(y, num_classes=self.n_classes)

# %% [markdown]
# ### Metrics to optimise
#
# AUC is often a better metric than accuracy. So instead of optimising for accuracy, let's monitor AUC and choose the best model based on AUC on validaton data. We'll use the callbacks `on_train_begin` and `on_epoch_end` to initialise  (at the start of each epoch) and store the AUC (at the end of epoch).

# %%
from sklearn.metrics import roc_auc_score

class roc_callback(Callback):
    
    def on_train_begin(self, logs={}):
        logs['val_auc'] = 0

    def on_epoch_end(self, epoch, logs={}):
        y_p = []
        y_v = []
        for i in range(len(validation_generator)):
            x_val, y_val = validation_generator[i]
            y_pred = self.model.predict(x_val)
            y_p.append(y_pred)
            y_v.append(y_val)
        y_p = np.concatenate(y_p)
        y_v = np.concatenate(y_v)
        roc_auc = roc_auc_score(y_v, y_p)
        print ('\nVal AUC for epoch{}: {}'.format(epoch, roc_auc))
        logs['val_auc'] = roc_auc

# %% [markdown]
# ## Final Run
#
# Let's now train the final model. Note that we will keep saving the best model's weights at `models/best_models.hdf5`, so you will need to create a directory `models`. Note that model weights are usually saved in hdf5 files.
#
# **Saving the best model** is done using the callback functionality that comes with `ModelCheckpoint`. We basically specify the `filepath` where the model weights are to be saved, ` monitor='val_auc'` specifies that you are choosing the best model based on validation accuracy, `save_best_only=True` saves only the best weights, and `mode='max'` specifies that the validation accuracy is to be maximised.

# %%
# model
model = resnet.ResnetBuilder.build_resnet_18((img_channels, img_rows, img_cols), nb_classes)
model.compile(loss='categorical_crossentropy',optimizer= sgd,
              metrics=['accuracy'])
training_generator = AugmentedDataGenerator('train', ablation=32)
validation_generator = AugmentedDataGenerator('val', ablation=32)

# checkpoint 
filepath = 'models/best_model.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor='val_auc', verbose=1, save_best_only=True, mode='max')
auc_logger = roc_callback()

# fit
model.fit(training_generator, epochs=3, validation_data=validation_generator, callbacks=[auc_logger, history, decay, checkpoint])
# Out:
# Epoch 1/3
# 2/2 [==============================] - ETA: 0s - loss: 2.1315 - accuracy: 0.4375
# Val AUC for epoch0: 0.51025390625
#
# Epoch 00001: val_auc improved from -inf to 0.51025, saving model to models/best_model.hdf5
# 2/2 [==============================] - 2s 1s/step - loss: 2.1315 - accuracy: 0.4375 - val_loss: 26.2089 - val_accuracy: 0.5000 - val_auc: 0.5103
# Epoch 2/3
# 2/2 [==============================] - ETA: 0s - loss: 2.0446 - accuracy: 0.6875
# Val AUC for epoch1: 0.7900390625
#
# Epoch 00002: val_auc improved from 0.51025 to 0.79004, saving model to models/best_model.hdf5
# 2/2 [==============================] - 1s 618ms/step - loss: 2.0446 - accuracy: 0.6875 - val_loss: 7.1659 - val_accuracy: 0.5000 - val_auc: 0.7900
# Epoch 3/3
# 2/2 [==============================] - ETA: 0s - loss: 1.3234 - accuracy: 0.8594
# Val AUC for epoch2: 0.817626953125
#
# Epoch 00003: val_auc improved from 0.79004 to 0.81763, saving model to models/best_model.hdf5
# 2/2 [==============================] - 1s 612ms/step - loss: 1.3234 - accuracy: 0.8594 - val_loss: 3.9098 - val_accuracy: 0.5000 - val_auc: 0.8176

# %%
plt.imshow(image)

# %%
h, w, _ = image.shape
img = image[int(h/2)-50:int(h/2)+50, int(w/2)-50:int(w/2)+50, : ]

model.predict(img[np.newaxis,: ])
# Out:
# array([[0., 1.]], dtype=float32)
